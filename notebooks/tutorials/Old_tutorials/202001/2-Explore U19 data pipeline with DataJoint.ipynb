# %% [markdown]
# # Explore U19 data Pipeline
#
# Here we introduce some useful DataJoint tools to explore the U19 pipeline
#
# First thing first, import datajoint

# %%
import datajoint as dj

# %% [markdown]
# # 1. Browse schemas you have access to - `dj.list_schemas()`

# %%
dj.list_schemas()
# Out:
# /Users/shanshen/anaconda3/lib/python3.7/site-packages/datajoint/connection.py:215: UserWarning: MySQL server has gone away. Reconnecting to the server.
#   warnings.warn("MySQL server has gone away. Reconnecting to the server.")
# ['abondy_tutorial',
#  'ahoag_admin_demo',
#  'ahoag_admin_flask_demo',
#  'ahoag_celery_test',
#  'ahoag_lightsheet_demo',
#  'ahoag_microscope_demo',
#  'ahoag_tutorial',
#  'brody_2pdemo',
#  'brody_trash',
#  'brody_tutorial2',
#  'brody_tutorial3',
#  'brody_tutorial5',
#  'ckopec_tutorial_db',
#  'diamanti_tutorial',
#  'dikshag_pipeline',
#  'dikshag_tutorial',
#  'gtm_testdb',
#  'jjulian_tutorail',
#  'jjulian_tutorial',
#  'jounhong_session1',
#  'jounhong_tutorial',
#  'jyanar_tutorial3',
#  'lpinto_tutorial',
#  'ms81_tutorial',
#  'mysql',
#  'performance_schema',
#  'shans_acquisition',
#  'shans_action',
#  'shans_behavior',
#  'shans_imaging',
#  'shans_lab',
#  'shans_reference',
#  'shans_subject',
#  'shans_task',
#  'shans_tutorial',
#  'shans_tutorial2',
#  'tdkim_tutorial',
#  'test',
#  'u19_acquisition',
#  'u19_action',
#  'u19_behavior',
#  'u19_lab',
#  'u19_reference',
#  'u19_subject',
#  'u19_task',
#  'u19lightserv_appcore',
#  'u19lightserv_lightsheet',
#  'venditto_tutorial',
#  'zhihaol_tutorial',
#  'zhihaol_tutorial_db']

# %% [markdown]
# ## Major schemas:
#
# Meta data: `u19_lab`, `u19_subject`, `u19_action`, `u19_task`
# Behavior: `u19_acquisition`, `u19_behavior` (also contains some imaging info)
#
# These schemas have been generated by matlab or python, but as a user, you don't have to get the code to generate these tables. To work with these tables, the simplest thing you would do is to reconstruct a module that represents this schema with the method `create_virtual_module`.

# %%
lab = dj.create_virtual_module('lab', 'u19_lab') # the first argument here is the __name__ of the virtual module
task = dj.create_virtual_module('task', 'u19_task') 
subject = dj.create_virtual_module('subject', 'u19_subject')
action = dj.create_virtual_module('action', 'u19_action')
acquisition = dj.create_virtual_module('acquisition', 'u19_acquisition')
behavior = dj.create_virtual_module('behavior', 'u19_behavior')

# %%
subject.Subject()
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 191)

# %% [markdown]
# Now this is as if you have the code that generated the schema and tables, and have just imported them!

# %% [markdown]
# # 2. Browse tables in a schema - `dj.Diagram`

# %% [markdown]
# **Table tiers**:
# Manual table: green box
# Lookup table: gray box
# Imported table: blue oval
# Computed table: red circle
# Part table: plain text

# %% [markdown]
# **Dependencies**:
# One-to-one primary: thick solid line
# One-to-many primary: thin solid line
# Secondary foreign key reference: dashed line
# renamed secondary foreign key references: orange dot

# %% [markdown]
# ## Show tables in the whole schema

# %%
dj.Diagram(subject)

# %% [markdown]
# ## Show diagram of arbitruary parts of the database

# %% [markdown]
# A combination of arbitruary tables:

# %%
dj.Diagram(subject.Subject) + dj.Diagram(subject.Death) + dj.Diagram(subject.HealthStatus) + dj.Diagram(subject.Weaning)

# %%
# same as above
dj.Diagram(subject.Subject) + subject.Death + subject.HealthStatus + subject.Weaning

# %% [markdown]
# The tables could be from different schemas:

# %%
dj.Diagram(subject.Subject) + acquisition.Session

# %% [markdown]
# # 3. Getting the detailed definition of a table - `table.describe()`

# %%
subject.Subject.describe();
# Out:
# subject_fullname     : varchar(64)                  # username_mouse_nickname
# ---
# subject_nickname     : varchar(16)
# -> lab.User
# genomics_id=null     : int                          # number from the facility
# sex="Unknown"        : enum('Male','Female','Unknown') # sex
# dob=null             : date                         # birth date
# head_plate_mark=null : blob                         # little drawing on the head plate for mouse identification
# -> lab.Location
# -> [nullable] lab.Protocol
# -> [nullable] subject.Line
# subject_description="" : varchar(255)                 # description
# initial_weight=null  : float

# %% [markdown]
# # 4. Browsing of data - queries

# %% [markdown]
# Query all subjects

# %%
subject.Subject()
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 191)

# %% [markdown]
# ## Restriction  `&`: filtering data

# %% [markdown]
# ### Restriction: Query one subject

# %%
# restrict by string
subject.Subject & 'subject_nickname="B205"'
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
#  (Total: 1)

# %%
# restrict by dictionary
subject.Subject & {'subject_nickname': 'B205'}
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
#  (Total: 1)

# %%
subject.Subject & {'sex': 'Male'}
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 110)

# %% [markdown]
# `OR` logic: a list of dictionaries

# %%
subject.Subject & [{'user_id': 'hnieh'}, {'user_id': 'emanuele'}]
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 57)

# %%
subject.Subject & "user_id in ('hnieh', 'emanuele')"
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 57)

# %% [markdown]
# ### Restriction: Query subjects born after a date

# %%
subject.Subject & 'dob > "2019-01-01"'
# Out:
# *subject_fulln subject_nickna user_id     genomics_id    sex        dob            head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +---------+ +------------+ +--------+ +------------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# lpinto_SP1     SP1            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       20.9
# lpinto_SP10    SP10           lpinto      None           Female     2019-09-02     =BLOB=     vivarium     1910         SNAP-GLAMP6S                  22.8
# lpinto_SP11    SP11           lpinto      None           Female     2019-09-02     =BLOB=     vivarium     1910         SNAP25-GLAMP6S                24.0
# lpinto_SP12    SP12           lpinto      None           Female     2019-08-17     =BLOB=     vivarium     1910         SNAP25-GLAMP6S                23.2
# lpinto_SP13    SP13           lpinto      None           Female     2019-08-17     =BLOB=     vivarium     1910         SNAP25-GLAMP6S                22.4
# lpinto_SP14    SP14           lpinto      None           Female     2019-08-17     =BLOB=     vivarium     1910         SNAP25-GLAMP6S                23.7
# lpinto_SP2     SP2            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       22.4
# lpinto_SP3     SP3            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       21.6
# lpinto_SP4     SP4            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       24.7
# lpinto_SP5     SP5            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       20.3
# lpinto_SP6     SP6            lpinto      None           Male       2019-03-27     =BLOB=     vivarium     1910         Unknown                       28.1
# lpinto_SP7     SP7            lpinto      None           Male       2019-03-27     =BLOB=     vivarium     1910         Unknown                       23.6
#    ...
#  (Total: 37)

# %% [markdown]
# ### Restriction: subjects within a range of dates

# %%
subject.Subject & 'dob between "2019-01-01" and "2019-04-01"'
# Out:
# *subject_fulln subject_nickna user_id     genomics_id    sex        dob            head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +---------+ +------------+ +--------+ +------------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# lpinto_SP1     SP1            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       20.9
# lpinto_SP2     SP2            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       22.4
# lpinto_SP3     SP3            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       21.6
# lpinto_SP4     SP4            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       24.7
# lpinto_SP5     SP5            lpinto      None           Female     2019-03-27     =BLOB=     vivarium     1910         Unknown                       20.3
# lpinto_SP6     SP6            lpinto      None           Male       2019-03-27     =BLOB=     vivarium     1910         Unknown                       28.1
# lpinto_SP7     SP7            lpinto      None           Male       2019-03-27     =BLOB=     vivarium     1910         Unknown                       23.6
# lpinto_SP8     SP8            lpinto      None           Male       2019-03-27     =BLOB=     vivarium     1910         Unknown                       27.4
# mioffe_M10_604 M10_604        mioffe      None           Female     2019-02-10     =BLOB=     vivarium     1910         Thy1-GP5.3                    24.1
# mioffe_M5_696  M5_696         mioffe      None           Female     2019-01-21     =BLOB=     vivarium     1910         Unknown                       15.0
# mioffe_M7_669  M7_669         mioffe      None           Male       2019-01-05     =BLOB=     vivarium     1910         Ai93-Emx1 (Cre                24.9
# mioffe_M8_689  M8_689         mioffe      None           Female     2019-01-22     =BLOB=     vivarium     1910         Ai93-Emx1 (Cre                18.7
#    ...
#  (Total: 25)

# %% [markdown]
# ### Restriction: Query subjects on multiple attributes

# %%
subject.Subject & 'dob > "2019-01-01"' & 'sex="Male"'
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob            head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# lpinto_SP6     SP6            lpinto       None           Male     2019-03-27     =BLOB=     vivarium     1910         Unknown                       28.1
# lpinto_SP7     SP7            lpinto       None           Male     2019-03-27     =BLOB=     vivarium     1910         Unknown                       23.6
# lpinto_SP8     SP8            lpinto       None           Male     2019-03-27     =BLOB=     vivarium     1910         Unknown                       27.4
# lpinto_VG52    VG52           lpinto       None           Male     2019-04-21     =BLOB=     vivarium     1910         VGAT-ChR2-EYFP                28.5
# lpinto_VG53    VG53           lpinto       None           Male     2019-04-21     =BLOB=     vivarium     1910         VGAT-ChR2-EYFP                25.7
# mioffe_M7_669  M7_669         mioffe       None           Male     2019-01-05     =BLOB=     vivarium     1910         Ai93-Emx1 (Cre                24.9
# testuser_T02   T02            testuser     None           Male     2019-01-25     =BLOB=     valhalla     1910         C57BL6/J                      22.0
# testuser_T03   T03            testuser     None           Male     2019-02-01     =BLOB=     valhalla     1910         C57BL6/J                      18.0
# testuser_T05   T05            testuser     None           Male     2019-01-23     =BLOB=     vivarium     1910         C57BL6/J                      19.0
# testuser_T06   T06            testuser     None           Male     2019-01-13     =BLOB=     vivarium     1910         D1-CRE                        25.0
# testuser_T07   T07            testuser     None           Male     2019-01-23     =BLOB=     vivarium     1910         VGAT-ChR2-EYFP                19.0
# testuser_T08   T08            testuser     None           Male     2019-01-23     =BLOB=     vivarium     1910         D2-CRE                        19.0
#    ...
#  (Total: 18)

# %% [markdown]
# ### Restriction: Query subjects restricted by other tables

# %%
# subjects that are dead
subject.Subject & subject.Death
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex        dob            head_plate location     protocol     line         subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +--------+ +------------+ +--------+ +----------+ +----------+ +----------+ +------------+ +------------+
# mioffe_M4_984  M4_984         mioffe       None           Female     2018-10-27     =BLOB=     vivarium     1910         C57BL6/J                    25.5
# mioffe_M5_696  M5_696         mioffe       None           Female     2019-01-21     =BLOB=     vivarium     1910         Unknown                     15.0
# testuser_T02   T02            testuser     None           Male       2019-01-25     =BLOB=     valhalla     1910         C57BL6/J                    22.0
# testuser_T03   T03            testuser     None           Male       2019-02-01     =BLOB=     valhalla     1910         C57BL6/J                    18.0
# testuser_T14   T14            testuser     None           Male       2019-01-23     =BLOB=     valhalla     1910         Unknown                     26.0
# testuser_T15   T15            testuser     None           Male       None           =BLOB=     valhalla     1910         Unknown                     26.0
# testuser_T17   T17            testuser     None           Male       2017-05-05     =BLOB=     valhalla     1910         D1-CRE                      23.0
# testuser_T18   T18            testuser     None           Male       2019-01-23     =BLOB=     valhalla     1910         Unknown                     25.0
# testuser_T19   T19            testuser     None           Male       2017-04-04     =BLOB=     valhalla     1910         Unknown                     25.0
# testuser_T20   T20            testuser     None           Male       2019-01-23     =BLOB=     valhalla     1910         Unknown                     28.0
#  (Total: 10)

# %%
# subjects that are alive
subject.Subject - subject.Death
# Out:
# *subject_fulln subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight
# +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+
# emanuele_B205  B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B208  B208           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B3151 B3151          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4486 B4486          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4487 B4487          emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0
# emanuele_B4488 B4488          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# emanuele_B4489 B4489          emanuele     None           Male     None     =BLOB=     vivarium     1910         Unknown                       27.0
# hnieh_E18      E18            hnieh        None           Male     None     =BLOB=     valhalla     1910         Unknown                       26.0
# hnieh_E26      E26            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       24.0
# hnieh_E36      E36            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       23.0
# hnieh_E38      E38            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
# hnieh_E39      E39            hnieh        None           Male     None     =BLOB=     vivarium     1910         Unknown                       26.0
#    ...
#  (Total: 181)

# %% [markdown]
# ## Join `*`:  gather information from different tables

# %%
subject.Subject * action.WaterAdministration
# Out:
# *subject_fulln *administratio subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight earned     supplement     received     watertype_name
# +------------+ +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+ +--------+ +------------+ +----------+ +------------+
# emanuele_B205  2018-06-20     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-21     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-23     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-24     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-25     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-27     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-28     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           1.0        0.0            1.0          Unknown
# emanuele_B205  2018-06-29     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-30     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-07-01     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           0.0        1.0            1.0          Unknown
# emanuele_B205  2018-07-03     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           1.3        0.0            1.3          Unknown
# emanuele_B205  2018-07-04     B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           1.3        0.0            1.3          Unknown
#    ...
#  (Total: 25422)

# %%
action.WaterAdministration()
# Out:
# *subject_fulln *administratio earned     supplement     received     watertype_name
# +------------+ +------------+ +--------+ +------------+ +----------+ +------------+
# emanuele_B205  2018-06-20     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-21     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-23     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-24     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-25     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-27     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-28     1.0        0.0            1.0          Unknown
# emanuele_B205  2018-06-29     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-06-30     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-07-01     0.0        1.0            1.0          Unknown
# emanuele_B205  2018-07-03     1.3        0.0            1.3          Unknown
# emanuele_B205  2018-07-04     1.3        0.0            1.3          Unknown
#    ...
#  (Total: 25422)

# %%
lab.Lab()
# Out:
# *lab          institution    address        time_zone      pi_name
# +-----------+ +------------+ +------------+ +------------+ +------------+
# tanklab       Princeton      Princeton Neur America/New_Yo D. W. Tank
# wanglab       Princeton      Neuroscience I America/New_Yo S. Wang
# wittenlab     Princeton      Princeton Neur America/New_Yo I. Witten
#  (Total: 3)

# %%
lab.Project()
# Out:
# *project       project_descri
# +------------+ +------------+
# accumulation o
# behavioral tas
#  (Total: 2)

# %% [markdown]
# Behavior of join:
# 1. match the common field(s) of the primary keys in the two tables
# 2. do a combination of the non-matched part of the primary key
# 3. listing out the secondary attributes for each combination
# 4. if two tables have secondary attributes that share a same name, it will throw an error. To join, we need to rename that attribute for at least one of the tables.
#
# For example,

# %%
subject.Subject * acquisition.Session
# Out:
# *subject_fulln *session_date  *session_numbe subject_nickna user_id      genomics_id    sex      dob      head_plate location     protocol     line           subject_descri initial_weight session_start_ session_end_ti session_locati task       level     set_id     stimulus_bank  stimulus_commi session_perfor session_narrat session_protoc session_co
# +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------+ +------+ +--------+ +----------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +-------+ +--------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+
# emanuele_B205  2018-06-27     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-06-27 10: 2018-06-27 11: VRTrain5       Towers     4         1                                        96.3                          poisson_blocks =BLOB=
# emanuele_B205  2018-06-28     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-06-28 11: 2018-06-28 12: VRTrain5       Towers     5         1                                        94.9                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-03     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-03 11: 2018-07-03 12: VRTrain5       Towers     6         1                                        95.0                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-04     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-04 11: 2018-07-04 12: VRTrain5       Towers     7         1                                        92.6                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-05     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-05 11: 2018-07-05 12: VRTrain5       Towers     8         1                                        94.8                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-06     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-06 11: 2018-07-06 12: VRTrain5       Towers     9         1                                        69.3                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-07     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-07 11: 2018-07-07 12: VRTrain5       Towers     10        1                                        61.7                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-11     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-11 11: 2018-07-11 12: VRTrain5       Towers     10        1                                        77.0                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-12     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-12 10: 2018-07-12 11: VRTrain5       Towers     9         1                                        66.7                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-13     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-13 10: 2018-07-13 11: VRTrain5       Towers     9         1                                        64.2                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-14     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-14 13: 2018-07-14 14: VRTrain5       Towers     9         1                                        58.8                          poisson_blocks =BLOB=
# emanuele_B205  2018-07-17     0              B205           emanuele     None           Male     None     =BLOB=     vivarium     1910         DAT-IRES-CRE                  27.0           2018-07-17 11: 2018-07-17 12: VRTrain5       Towers     9         1                                        77.7                          poisson_blocks =BLOB=
#    ...
#  (Total: 9761)

# %% [markdown]
# ## Projection `.proj()`: focus on attributes of interest

# %%
(subject.Subject * acquisition.Session).proj()
# Out:
# *subject_fulln *session_date  *session_numbe
# +------------+ +------------+ +------------+
# emanuele_B205  2018-06-27     0
# emanuele_B205  2018-06-28     0
# emanuele_B205  2018-07-03     0
# emanuele_B205  2018-07-04     0
# emanuele_B205  2018-07-05     0
# emanuele_B205  2018-07-06     0
# emanuele_B205  2018-07-07     0
# emanuele_B205  2018-07-11     0
# emanuele_B205  2018-07-12     0
# emanuele_B205  2018-07-13     0
# emanuele_B205  2018-07-14     0
# emanuele_B205  2018-07-17     0
#    ...
#  (Total: 9761)

# %%
subject.Subject.proj('dob', 'sex')
# Out:
# *subject_fulln sex      dob
# +------------+ +------+ +------+
# emanuele_B205  Male     None
# emanuele_B208  Male     None
# emanuele_B3151 Male     None
# emanuele_B4486 Male     None
# emanuele_B4487 Male     None
# emanuele_B4488 Male     None
# emanuele_B4489 Male     None
# hnieh_E18      Male     None
# hnieh_E26      Male     None
# hnieh_E36      Male     None
# hnieh_E38      Male     None
# hnieh_E39      Male     None
#    ...
#  (Total: 191)

# %% [markdown]
# ### rename attribute with ***proj()***

# %%
subject.Subject.proj(gender='sex', birth_date='dob')
# Out:
# *subject_fulln gender     birth_date
# +------------+ +--------+ +------------+
# emanuele_B205  Male       None
# emanuele_B208  Male       None
# emanuele_B3151 Male       None
# emanuele_B4486 Male       None
# emanuele_B4487 Male       None
# emanuele_B4488 Male       None
# emanuele_B4489 Male       None
# hnieh_E18      Male       None
# hnieh_E26      Male       None
# hnieh_E36      Male       None
# hnieh_E38      Male       None
# hnieh_E39      Male       None
#    ...
#  (Total: 191)

# %% [markdown]
# ### perform simple computations with ***proj***

# %% [markdown]
# **Example 1: Get date of a weighing activity:**

# %%
weighing_with_date = action.Weighing.proj(weighing_date='date(weighing_time)') # more options, check MySQL syntax

# %%
weighing_with_date
# Out:
# *subject_fulln *weighing_time weighing_date
# +------------+ +------------+ +------------+
# emanuele_B205  2018-07-09 12: 2018-07-09
# emanuele_B205  2018-07-15 12: 2018-07-15
# emanuele_B205  2018-07-16 11: 2018-07-16
# emanuele_B205  2018-07-22 12: 2018-07-22
# emanuele_B205  2018-07-23 11: 2018-07-23
# emanuele_B205  2018-07-29 11: 2018-07-29
# emanuele_B205  2018-07-30 11: 2018-07-30
# emanuele_B205  2018-08-05 11: 2018-08-05
# emanuele_B205  2018-08-06 11: 2018-08-06
# emanuele_B205  2018-08-12 11: 2018-08-12
# emanuele_B205  2018-08-13 11: 2018-08-13
# emanuele_B205  2018-08-15 12: 2018-08-15
#    ...
#  (Total: 25409)

# %% [markdown]
# **Example 2: Age of the animal when performing each session?**

# %%
# First get the date of birth and the session date into the same query
q = subject.Subject * acquisition.Session
q = q.proj('dob')
q
# Out:
# *subject_fulln *session_date  *session_numbe dob
# +------------+ +------------+ +------------+ +------+
# emanuele_B205  2018-06-27     0              None
# emanuele_B205  2018-06-28     0              None
# emanuele_B205  2018-07-03     0              None
# emanuele_B205  2018-07-04     0              None
# emanuele_B205  2018-07-05     0              None
# emanuele_B205  2018-07-06     0              None
# emanuele_B205  2018-07-07     0              None
# emanuele_B205  2018-07-11     0              None
# emanuele_B205  2018-07-12     0              None
# emanuele_B205  2018-07-13     0              None
# emanuele_B205  2018-07-14     0              None
# emanuele_B205  2018-07-17     0              None
#    ...
#  (Total: 9761)

# %%
# Then compute the age
q_with_age = q.proj('dob', age='datediff(session_date, dob)') & 'dob is not NULL'
q_with_age
# Out:
# *subject_fulln *session_date  *session_numbe dob            age
# +------------+ +------------+ +------------+ +------------+ +-----+
# hnieh_E58      2017-10-17     0              2016-11-14     337
# hnieh_E58      2017-10-18     0              2016-11-14     338
# hnieh_E58      2017-10-19     0              2016-11-14     339
# hnieh_E58      2017-10-20     0              2016-11-14     340
# hnieh_E58      2017-10-23     0              2016-11-14     343
# hnieh_E58      2017-10-24     0              2016-11-14     344
# hnieh_E58      2017-10-25     0              2016-11-14     345
# hnieh_E58      2017-10-26     0              2016-11-14     346
# hnieh_E58      2017-10-27     0              2016-11-14     347
# hnieh_E58      2017-10-31     0              2016-11-14     351
# hnieh_E58      2017-11-01     0              2016-11-14     352
# hnieh_E58      2017-11-02     0              2016-11-14     353
#    ...
#  (Total: 5822)

# %% [markdown]
# ## Aggregation `.aggr()`: simple computation of one table against another table

# %% [markdown]
# Example: how many sessions does each subject do so far?

# %%
subject.Subject.aggr(acquisition.Session, n='count(*)', lastest_session='min(session_date)')
# Out:
# *subject_fulln n      lastest_sessio
# +------------+ +----+ +------------+
# emanuele_B205  41     2018-06-27
# emanuele_B208  40     2018-06-27
# emanuele_B3151 40     2018-06-27
# emanuele_B4486 39     2018-06-27
# emanuele_B4487 40     2018-06-27
# emanuele_B4488 39     2018-06-27
# emanuele_B4489 41     2018-06-26
# hnieh_E18      7      2017-08-03
# hnieh_E26      43     2017-08-03
# hnieh_E36      26     2017-08-03
# hnieh_E38      62     2017-08-03
# hnieh_E39      64     2017-08-04
#    ...
#  (Total: 137)

# %% [markdown]
# # 5. Fetching data

# %% [markdown]
# ## Fetch all fields: `fetch()`

# %%
# fetch all data from a table
subjs = subject.Subject.fetch()
subjs
# Out:
# array([('emanuele_B205', 'B205', 'emanuele', None, 'Male', None, array([[[253, 253, 253],
#         [246, 251, 252],
#         [193, 241, 251],
#         ...,
#         [ 64, 215, 246],
#         [105, 224, 248],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [239, 252, 254],
#         [ 60, 217, 249],
#         ...,
#         [ 34, 212, 248],
#         [ 58, 217, 249],
#         [254, 253, 253]],
#
#        [[254, 255, 255],
#         [172, 239, 252],
#         [ 55, 216, 249],
#         ...,
#         [ 64, 218, 249],
#         [ 37, 212, 248],
#         [142, 231, 249]],
#
#        ...,
#
#        [[175, 239, 252],
#         [  0, 202, 247],
#         [ 40, 213, 248],
#         ...,
#         [ 13, 207, 247],
#         [ 78, 221, 250],
#         [255, 254, 253]],
#
#        [[197, 244, 253],
#         [  0, 202, 247],
#         [ 78, 220, 249],
#         ...,
#         [  3, 205, 247],
#         [ 86, 222, 250],
#         [255, 254, 253]],
#
#        [[232, 250, 254],
#         [ 30, 210, 248],
#         [149, 234, 252],
#         ...,
#         [ 20, 208, 248],
#         [157, 236, 252],
#         [255, 255, 253]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 27. ),
#        ('emanuele_B208', 'B208', 'emanuele', None, 'Male', None, array([[[252, 252, 252],
#         [245, 214, 208],
#         [251, 246, 245],
#         ...,
#         [252, 250, 250],
#         [245, 210, 203],
#         [250, 246, 245]],
#
#        [[255, 253, 253],
#         [225,  90,  63],
#         [242, 183, 171],
#         ...,
#         [249, 223, 218],
#         [221,  69,  39],
#         [247, 223, 217]],
#
#        [[254, 251, 249],
#         [224,  86,  58],
#         [234, 138, 119],
#         ...,
#         [229, 111,  88],
#         [219,  59,  27],
#         [243, 200, 191]],
#
#        ...,
#
#        [[246, 202, 193],
#         [218,  54,  21],
#         [218,  54,  21],
#         ...,
#         [217,  50,  17],
#         [240, 171, 157],
#         [252, 245, 243]],
#
#        [[250, 224, 219],
#         [222,  78,  49],
#         [217,  49,  16],
#         ...,
#         [221,  73,  43],
#         [245, 198, 188],
#         [254, 255, 255]],
#
#        [[255, 255, 255],
#         [235, 144, 125],
#         [223,  83,  55],
#         ...,
#         [229, 115,  92],
#         [247, 212, 205],
#         [254, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 27. ),
#        ('emanuele_B3151', 'B3151', 'emanuele', None, 'Male', None, array([[[253, 253, 253],
#         [254, 253, 253],
#         [255, 253, 255],
#         ...,
#         [152, 250, 177],
#         [119, 250, 153],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [251, 255, 252],
#         [218, 254, 228],
#         ...,
#         [ 87, 251, 129],
#         [ 28, 250,  85],
#         [250, 253, 251]],
#
#        [[255, 255, 255],
#         [169, 253, 191],
#         [ 17, 249,  69],
#         ...,
#         [ 82, 251, 126],
#         [ 35, 250,  91],
#         [250, 253, 251]],
#
#        ...,
#
#        [[ 15, 249,  75],
#         [  0, 249,  56],
#         [ 76, 251, 121],
#         ...,
#         [ 83, 251, 126],
#         [ 71, 251, 117],
#         [ 43, 248,  96]],
#
#        [[ 12, 249,  72],
#         [  0, 249,  55],
#         [ 94, 251, 134],
#         ...,
#         [254, 255, 255],
#         [126, 252, 158],
#         [ 37, 248,  91]],
#
#        [[ 50, 250, 101],
#         [  5, 249,  60],
#         [151, 252, 177],
#         ...,
#         [255, 255, 255],
#         [186, 254, 204],
#         [ 87, 249, 128]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 27. ),
#        ('emanuele_B4486', 'B4486', 'emanuele', None, 'Male', None, array([[[252, 251, 251],
#         [252, 248, 248],
#         [247, 195, 193],
#         ...,
#         [252, 252, 252],
#         [252, 241, 241],
#         [246, 193, 191]],
#
#        [[252, 218, 217],
#         [243, 117, 112],
#         [246, 154, 150],
#         ...,
#         [253, 236, 236],
#         [253, 227, 226],
#         [237,  72,  66]],
#
#        [[251, 211, 210],
#         [241,  91,  86],
#         [246, 145, 141],
#         ...,
#         [244, 131, 127],
#         [248, 177, 174],
#         [238,  82,  76]],
#
#        ...,
#
#        [[255, 252, 252],
#         [238,  65,  59],
#         [235,  26,  18],
#         ...,
#         [249, 182, 180],
#         [249, 185, 182],
#         [237,  65,  58]],
#
#        [[255, 252, 252],
#         [238,  60,  54],
#         [235,  28,  21],
#         ...,
#         [255, 255, 255],
#         [252, 219, 218],
#         [241, 123, 119]],
#
#        [[255, 254, 254],
#         [242, 102,  97],
#         [244, 135, 132],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 27. ),
#        ('emanuele_B4487', 'B4487', 'emanuele', None, 'Male', None, array([[[210, 210, 210],
#         [115, 115, 115],
#         [215, 215, 215],
#         ...,
#         [253, 253, 253],
#         [254, 254, 254],
#         [255, 255, 255]],
#
#        [[104, 104, 104],
#         [ 37,  37,  37],
#         [141, 141, 141],
#         ...,
#         [255, 255, 255],
#         [247, 247, 247],
#         [214, 214, 214]],
#
#        [[ 12,  12,  12],
#         [ 50,  50,  50],
#         [120, 120, 120],
#         ...,
#         [194, 194, 194],
#         [209, 209, 209],
#         [ 59,  59,  59]],
#
#        ...,
#
#        [[ 99,  99,  99],
#         [124, 124, 124],
#         [ 50,  50,  50],
#         ...,
#         [ 43,  43,  43],
#         [168, 168, 168],
#         [ 70,  70,  70]],
#
#        [[117, 117, 117],
#         [110, 110, 110],
#         [ 74,  74,  74],
#         ...,
#         [ 47,  47,  47],
#         [200, 200, 200],
#         [216, 216, 216]],
#
#        [[195, 195, 195],
#         [192, 192, 192],
#         [177, 177, 177],
#         ...,
#         [162, 162, 162],
#         [234, 234, 234],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 27. ),
#        ('emanuele_B4488', 'B4488', 'emanuele', None, 'Male', None, array([[[253, 253, 253],
#         [215, 172, 247],
#         [166,  70, 239],
#         ...,
#         [251, 249, 252],
#         [180, 100, 241],
#         [200, 143, 243]],
#
#        [[255, 255, 255],
#         [189, 115, 245],
#         [136,   3, 236],
#         ...,
#         [242, 228, 253],
#         [144,  20, 238],
#         [161,  58, 238]],
#
#        [[255, 255, 255],
#         [191, 119, 245],
#         [139,   9, 236],
#         ...,
#         [221, 183, 250],
#         [139,   8, 236],
#         [164,  65, 238]],
#
#        ...,
#
#        [[155,  43, 239],
#         [142,  15, 237],
#         [139,  10, 236],
#         ...,
#         [176,  89, 242],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[144,  22, 237],
#         [142,  16, 237],
#         [138,   7, 236],
#         ...,
#         [174,  85, 242],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[196, 131, 246],
#         [165,  64, 240],
#         [177,  89, 242],
#         ...,
#         [192, 121, 245],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('emanuele_B4489', 'B4489', 'emanuele', None, 'Male', None, array([[[253, 253, 253],
#         [253, 253, 253],
#         [243, 244, 249],
#         ...,
#         [ 81,  98, 186],
#         [216, 220, 239],
#         [187, 193, 226]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [222, 226, 243],
#         ...,
#         [  7,  31, 159],
#         [151, 162, 215],
#         [ 50,  70, 175]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [220, 224, 242],
#         ...,
#         [ 15,  39, 162],
#         [ 98, 113, 194],
#         [ 48,  68, 174]],
#
#        ...,
#
#        [[255, 255, 255],
#         [103, 118, 196],
#         [ 52,  72, 177],
#         ...,
#         [  9,  32, 159],
#         [ 92, 108, 192],
#         [ 68,  87, 182]],
#
#        [[255, 255, 255],
#         [100, 115, 195],
#         [ 49,  69, 176],
#         ...,
#         [104, 119, 197],
#         [ 27,  50, 167],
#         [ 49,  69, 174]],
#
#        [[255, 255, 255],
#         [135, 147, 209],
#         [ 84, 101, 189],
#         ...,
#         [179, 186, 225],
#         [132, 144, 208],
#         [ 79,  96, 186]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('hnieh_E18', 'E18', 'hnieh', None, 'Male', None, None, 'valhalla', '1910', 'Unknown', '', 26. ),
#        ('hnieh_E26', 'E26', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [253, 250, 248],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [247, 239, 229],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 24. ),
#        ('hnieh_E36', 'E36', 'hnieh', None, 'Male', None, None, 'vivarium', '1910', 'Unknown', '', 23. ),
#        ('hnieh_E38', 'E38', 'hnieh', None, 'Male', None, array([[[193, 165, 227],
#         [236, 229, 245],
#         [252, 252, 252],
#         ...,
#         [249, 249, 249],
#         [ 85,  85,  85],
#         [119, 118, 118]],
#
#        [[ 89,  10, 186],
#         [185, 152, 226],
#         [255, 255, 255],
#         ...,
#         [247, 247, 247],
#         [ 28,  27,  27],
#         [ 39,  38,  38]],
#
#        [[ 94,  19, 189],
#         [153, 104, 213],
#         [255, 255, 255],
#         ...,
#         [242, 242, 242],
#         [ 36,  35,  35],
#         [ 19,  18,  18]],
#
#        ...,
#
#        [[247, 243, 252],
#         [116,  51, 198],
#         [ 99,  26, 191],
#         ...,
#         [255, 255, 255],
#         [146, 146, 146],
#         [  6,   5,   5]],
#
#        [[247, 243, 252],
#         [115,  48, 197],
#         [117,  51, 198],
#         ...,
#         [255, 255, 255],
#         [138, 137, 137],
#         [  1,   0,   0]],
#
#        [[251, 249, 254],
#         [132,  74, 204],
#         [193, 164, 229],
#         ...,
#         [255, 255, 255],
#         [ 78,  78,  78],
#         [ 65,  65,  65]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 26. ),
#        ('hnieh_E39', 'E39', 'hnieh', None, 'Male', None, array([[[ 34,  35, 255],
#         [151, 152, 255],
#         [ 36,  37, 255],
#         ...,
#         [122, 255, 105],
#         [251, 255, 251],
#         [ 90, 255,  69]],
#
#        [[ 12,  13, 255],
#         [ 27,  28, 255],
#         [ 48,  49, 255],
#         ...,
#         [ 65, 255,  41],
#         [238, 255, 237],
#         [ 64, 255,  39]],
#
#        [[ 15,  16, 255],
#         [  0,   0, 255],
#         [ 31,  31, 255],
#         ...,
#         [ 41, 255,  13],
#         [210, 255, 204],
#         [ 61, 255,  36]],
#
#        ...,
#
#        [[135, 135, 255],
#         [ 25,  26, 255],
#         [ 93,  94, 255],
#         ...,
#         [143, 255, 128],
#         [ 88, 255,  66],
#         [ 72, 255,  48]],
#
#        [[136, 136, 255],
#         [ 14,  15, 255],
#         [112, 112, 255],
#         ...,
#         [119, 255, 102],
#         [131, 255, 115],
#         [ 72, 255,  49]],
#
#        [[181, 181, 255],
#         [  5,   5, 255],
#         [146, 147, 255],
#         ...,
#         [216, 255, 211],
#         [218, 255, 213],
#         [ 93, 255,  72]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 26. ),
#        ('hnieh_E42', 'E42', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('hnieh_E43', 'E43', 'hnieh', None, 'Female', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[192, 190, 188],
#         [252, 252, 252],
#         [255, 255, 255],
#         ...,
#         [254, 229, 228],
#         [253, 182, 179],
#         [255, 255, 255]],
#
#        [[ 48,  42,  34],
#         [240, 240, 239],
#         [255, 255, 255],
#         ...,
#         [253, 184, 181],
#         [249,  40,  31],
#         [255, 248, 248]],
#
#        ...,
#
#        [[225, 224, 223],
#         [ 22,  15,   6],
#         [ 32,  26,  17],
#         ...,
#         [252, 152, 148],
#         [248,  15,   5],
#         [255, 239, 239]],
#
#        [[222, 221, 219],
#         [ 46,  40,  32],
#         [104,  99,  94],
#         ...,
#         [254, 216, 214],
#         [252, 142, 137],
#         [255, 255, 254]],
#
#        [[220, 219, 217],
#         [100,  96,  90],
#         [233, 233, 232],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 21. ),
#        ('hnieh_E44', 'E44', 'hnieh', None, 'Female', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [175, 174, 172]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [241, 241, 241],
#         [204, 204, 202],
#         [ 42,  40,  35]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [165, 164, 162],
#         [ 88,  86,  83],
#         [ 57,  54,  50]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [168, 167, 165],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [222, 222, 221],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 21. ),
#        ('hnieh_E45', 'E45', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [249,  55,  47],
#         [248,  18,  12],
#         [254, 210, 209]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [248,  20,  11],
#         [248,   0,   0],
#         [252, 157, 153]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [248,  22,  13],
#         [248,   1,   0],
#         [250, 100,  94]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [250,  78,  71],
#         [252, 142, 138],
#         [249,  60,  52]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [250,  72,  64],
#         [252, 164, 161],
#         [249,  56,  48]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [250,  73,  66],
#         [253, 199, 197],
#         [250,  83,  76]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 30.7),
#        ('hnieh_E47', 'E47', 'hnieh', None, 'Male', None, array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 254, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('hnieh_E48', 'E48', 'hnieh', None, 'Male', None, array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('hnieh_E49', 'E49', 'hnieh', None, 'Male', None, array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27. ),
#        ('hnieh_E50', 'E50', 'hnieh', None, 'Female', None, array([[[113,   6, 243],
#         [149,  69, 245],
#         [253, 252, 253],
#         ...,
#         [  0, 238,  16],
#         [ 92, 244, 110],
#         [255, 253, 255]],
#
#        [[114,   8, 243],
#         [114,   8, 243],
#         [171, 108, 248],
#         ...,
#         [136, 248, 149],
#         [  8, 240,  34],
#         [230, 252, 233]],
#
#        [[115,   9, 243],
#         [115,   8, 243],
#         [112,   4, 243],
#         ...,
#         [176, 250, 185],
#         [ 19, 240,  44],
#         [117, 245, 131]],
#
#        ...,
#
#        [[117,  12, 243],
#         [113,   6, 243],
#         [114,   8, 243],
#         ...,
#         [181, 250, 189],
#         [  0, 238,  19],
#         [  0, 239,  20]],
#
#        [[115,   8, 243],
#         [118,  14, 243],
#         [152,  74, 246],
#         ...,
#         [123, 247, 137],
#         [ 11, 239,  33],
#         [ 81, 243, 100]],
#
#        [[116,  10, 243],
#         [212, 180, 251],
#         [246, 240, 254],
#         ...,
#         [  0, 238,  20],
#         [ 94, 245, 112],
#         [255, 254, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 21. ),
#        ('hnieh_E51', 'E51', 'hnieh', None, 'Female', None, array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 21. ),
#        ('hnieh_E52', 'E52', 'hnieh', None, 'Male', None, array([[[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [221, 221, 221],
#         [174, 174, 174]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [139, 139, 139],
#         [  0,   0,   0]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [111, 111, 111],
#         [  3,   3,   3]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [  0,   0,   0],
#         [  6,   6,   6],
#         [ 13,  13,  13]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 39,  39,  39],
#         [  4,   4,   4],
#         [  9,   9,   9]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [151, 151, 151],
#         [  0,   0,   0],
#         [ 53,  53,  53]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 28. ),
#        ('hnieh_E53', 'E53', 'hnieh', None, 'Male', None, array([[[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [142,  16, 233],
#         [198, 138, 242],
#         [252, 253, 250]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [138,   8, 233],
#         [170,  76, 240],
#         [253, 255, 252]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [140,  12, 233],
#         [172,  80, 240],
#         [253, 255, 252]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [152,  38, 235],
#         [201, 141, 245],
#         [147,  29, 234]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [151,  37, 235],
#         [175,  85, 240],
#         [147,  29, 234]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [176,  89, 240],
#         [138,   9, 233],
#         [164,  67, 236]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 26. ),
#        ('hnieh_E54', 'E54', 'hnieh', None, 'Male', None, None, 'valhalla', '1910', 'Ai93-Emx1', '', 27. ),
#        ('hnieh_E55', 'E55', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [254, 255, 254],
#         [194, 245, 184],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [231, 238,  78],
#         [242, 246, 160],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [236, 242, 113],
#         [255, 255, 252],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 28. ),
#        ('hnieh_E56', 'E56', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [254, 253, 241],
#         [242, 233, 111],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 254],
#         [252, 248, 216],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 28. ),
#        ('hnieh_E57', 'E57', 'hnieh', None, 'Male', None, array([[[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [253, 252, 252],
#         [122, 252, 236],
#         [116, 248, 232]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [ 39, 254, 228],
#         [ 37, 251, 224]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 255, 255],
#         [ 29, 253, 226],
#         [ 20, 251, 223]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [126, 254, 238],
#         [  0, 253, 221],
#         [  7, 253, 222]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [168, 254, 243],
#         [  0, 253, 221],
#         [  3, 253, 222]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [221, 255, 251],
#         [ 11, 253, 223],
#         [ 45, 251, 226]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 29. ),
#        ('hnieh_E58', 'E58', 'hnieh', None, 'Male', datetime.date(2016, 11, 14), None, 'vivarium', '1910', 'Ai93-Emx1', '', 28.2),
#        ('hnieh_E59', 'E59', 'hnieh', None, 'Male', None, array([[[255, 255, 255],
#         [237, 248, 240],
#         [145, 209, 162],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[249, 253, 251],
#         [158, 215, 173],
#         [ 23, 155,  53],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[221, 242, 226],
#         [ 53, 172,  87],
#         [  0, 148,  39],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 54, 173,  89],
#         [181, 225, 194],
#         [ 46, 170,  82],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[222, 242, 228],
#         [223, 242, 228],
#         [ 43, 168,  80],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [232, 246, 236],
#         [ 52, 172,  87],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 28. ),
#        ('hnieh_E61', 'E61', 'hnieh', None, 'Female', datetime.date(2017, 7, 27), array([[[247,   3,  56],
#         [249, 100, 109],
#         [255, 243, 245],
#         ...,
#         [245,  10,   9],
#         [245,   9,   9],
#         [245,  12,  12]],
#
#        [[245,  10,  17],
#         [245,  10,   9],
#         [247,  70,  71],
#         ...,
#         [247,  20,  68],
#         [251, 101, 169],
#         [245,  12,  11]],
#
#        [[245,  10,  10],
#         [245,   9,   9],
#         [245,   4,   4],
#         ...,
#         [248,  23,  84],
#         [253, 128, 215],
#         [245,  13,  11]],
#
#        ...,
#
#        [[245,   9,   9],
#         [245,  12,  12],
#         [252, 123, 195],
#         ...,
#         [249, 105, 113],
#         [246,  26,  24],
#         [254, 244, 244]],
#
#        [[245,  10,   9],
#         [245,   6,   0],
#         [250,  52, 135],
#         ...,
#         [254, 222, 226],
#         [251, 160, 159],
#         [255, 254, 254]],
#
#        [[245,  15,  21],
#         [246,  27,  41],
#         [245,   8,   7],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 22.5),
#        ('hnieh_E62', 'E62', 'hnieh', None, 'Female', datetime.date(2017, 7, 27), array([[[253, 253, 253],
#         [253, 253, 253],
#         [254, 255, 253],
#         ...,
#         [171,  99, 234],
#         [242, 231, 250],
#         [252, 252, 251]],
#
#        [[255, 255, 255],
#         [253, 250, 255],
#         [245, 237, 253],
#         ...,
#         [131,  20, 227],
#         [234, 216, 250],
#         [255, 255, 254]],
#
#        [[255, 255, 255],
#         [232, 211, 249],
#         [170,  95, 236],
#         ...,
#         [135,  28, 228],
#         [227, 202, 249],
#         [223, 195, 246]],
#
#        ...,
#
#        [[136,  30, 228],
#         [148,  52, 231],
#         [201, 153, 243],
#         ...,
#         [154,  63, 232],
#         [215, 178, 246],
#         [162,  80, 232]],
#
#        [[142,  41, 229],
#         [149,  54, 231],
#         [231, 209, 249],
#         ...,
#         [161,  77, 234],
#         [207, 163, 245],
#         [160,  76, 232]],
#
#        [[211, 172, 245],
#         [201, 152, 243],
#         [138,  35, 228],
#         ...,
#         [181, 116, 238],
#         [134,  26, 228],
#         [172, 101, 234]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 23.4),
#        ('hnieh_E63', 'E63', 'hnieh', None, 'Male', datetime.date(2017, 4, 2), array([[[241,  82, 243],
#         [245, 126, 246],
#         [240,  68, 242],
#         ...,
#         [125, 124, 195],
#         [246, 246, 251],
#         [255, 255, 255]],
#
#        [[240,  70, 242],
#         [242,  86, 244],
#         [240,  63, 242],
#         ...,
#         [116, 115, 190],
#         [245, 245, 250],
#         [255, 255, 255]],
#
#        [[240,  65, 242],
#         [240,  64, 242],
#         [240,  62, 242],
#         ...,
#         [116, 115, 191],
#         [245, 245, 250],
#         [255, 255, 255]],
#
#        ...,
#
#        [[247, 159, 248],
#         [242,  85, 243],
#         [252, 216, 252],
#         ...,
#         [160, 159, 210],
#         [250, 250, 253],
#         [255, 255, 255]],
#
#        [[249, 179, 250],
#         [243,  95, 245],
#         [253, 225, 253],
#         ...,
#         [174, 174, 218],
#         [251, 251, 253],
#         [255, 255, 255]],
#
#        [[250, 188, 250],
#         [244, 107, 245],
#         [253, 234, 253],
#         ...,
#         [239, 239, 248],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Ai93-Emx1', '', 30.6),
#        ('hnieh_E64', 'E64', 'hnieh', None, 'Male', datetime.date(2017, 7, 27), array([[[251, 180, 180],
#         [247,   5,   5],
#         [247,   2,   2],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [253, 253, 253]],
#
#        [[251, 137, 137],
#         [247,   0,   0],
#         [247,   1,   1],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[250, 112, 112],
#         [247,   0,   0],
#         [247,   1,   1],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        ...,
#
#        [[253, 203, 203],
#         [247,   7,   7],
#         [253, 202, 202],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[253, 202, 202],
#         [247,   8,   8],
#         [253, 205, 205],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[253, 209, 209],
#         [247,  25,  25],
#         [253, 207, 207],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 23. ),
#        ('hnieh_E65', 'E65', 'hnieh', None, 'Male', datetime.date(2017, 7, 27), array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [200, 172, 221],
#         [158, 107, 196],
#         [252, 252, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [137,  74, 184],
#         [149,  92, 191],
#         [254, 253, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [112,  36, 169],
#         [176, 134, 207],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [251, 248, 252],
#         [125,  55, 176],
#         [153, 100, 193]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [247, 243, 250],
#         [124,  54, 176],
#         [201, 173, 222]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [233, 221, 242],
#         [251, 249, 252]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 25. ),
#        ('hnieh_E66', 'E66', 'hnieh', None, 'Male', datetime.date(2017, 6, 15), array([[[251, 252, 253],
#         [187, 246, 252],
#         [244, 252, 253],
#         ...,
#         [254, 253, 253],
#         [255, 253, 254],
#         [251, 251, 251]],
#
#        [[249, 254, 255],
#         [ 52, 236, 253],
#         [229, 252, 255],
#         ...,
#         [247, 253, 251],
#         [238, 251, 247],
#         [254, 253, 254]],
#
#        [[250, 254, 255],
#         [ 53, 236, 253],
#         [216, 251, 255],
#         ...,
#         [179, 235, 219],
#         [110, 217, 187],
#         [255, 255, 255]],
#
#        ...,
#
#        [[100, 240, 254],
#         [  0, 230, 253],
#         [135, 244, 254],
#         ...,
#         [162, 231, 211],
#         [101, 215, 183],
#         [255, 255, 255]],
#
#        [[ 51, 236, 253],
#         [  0, 230, 253],
#         [174, 247, 254],
#         ...,
#         [158, 230, 209],
#         [ 95, 213, 180],
#         [255, 255, 255]],
#
#        [[ 57, 236, 253],
#         [ 86, 239, 254],
#         [245, 254, 255],
#         ...,
#         [213, 244, 235],
#         [185, 237, 222],
#         [254, 254, 254]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 28.4),
#        ('hnieh_E67', 'E67', 'hnieh', None, 'Female', datetime.date(2017, 11, 20), array([[[163, 236, 225],
#         [114, 227, 211],
#         [250, 252, 252],
#         ...,
#         [253, 253, 253],
#         [240, 241, 252],
#         [187, 192, 247]],
#
#        [[111, 229, 212],
#         [  1, 210, 178],
#         [233, 251, 248],
#         ...,
#         [255, 255, 255],
#         [216, 220, 253],
#         [ 53,  72, 241]],
#
#        [[116, 230, 213],
#         [  2, 209, 177],
#         [195, 244, 236],
#         ...,
#         [211, 216, 252],
#         [216, 220, 253],
#         [ 56,  74, 241]],
#
#        ...,
#
#        [[110, 229, 211],
#         [ 78, 223, 201],
#         [144, 235, 221],
#         ...,
#         [ 88, 103, 245],
#         [ 12,  30, 241],
#         [190, 196, 249]],
#
#        [[103, 228, 209],
#         [135, 233, 219],
#         [255, 255, 255],
#         ...,
#         [170, 178, 250],
#         [  0,  17, 240],
#         [218, 222, 250]],
#
#        [[190, 243, 235],
#         [214, 248, 243],
#         [255, 255, 255],
#         ...,
#         [242, 243, 254],
#         [159, 168, 249],
#         [247, 247, 252]]], dtype=uint8), 'vivarium', '1910', 'Ai93-Emx1', '', 18.6),
#        ('hnieh_E68', 'E68', 'hnieh', None, 'Female', datetime.date(2018, 1, 18), array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [ 48,  57, 181],
#         [146, 155, 217],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 28,  46, 179],
#         [ 43,  61, 184],
#         [251, 252, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 14,  34, 174],
#         [ 43,  61, 184],
#         [249, 250, 252]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 31,  50, 180],
#         [ 48,  65, 186],
#         [252, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [  0,  14, 167],
#         [ 92, 106, 200],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 70,  83, 192],
#         [206, 210, 238],
#         [254, 254, 254]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 22.2),
#        ('hnieh_E69', 'E69', 'hnieh', None, 'Female', datetime.date(2018, 1, 18), array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [250, 252, 250],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 21.4),
#        ('hnieh_E70', 'E70', 'hnieh', None, 'Female', datetime.date(2017, 11, 20), array([[[195, 246, 235],
#         [  0, 218, 168],
#         [ 48, 226, 187],
#         ...,
#         [218, 140, 242],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[244, 253, 251],
#         [ 24, 222, 179],
#         [  5, 219, 172],
#         ...,
#         [205,  98, 238],
#         [253, 250, 254],
#         [248, 234, 253]],
#
#        [[197, 247, 236],
#         [ 30, 223, 180],
#         [  0, 217, 167],
#         ...,
#         [208, 107, 238],
#         [234, 189, 248],
#         [192,  56, 233]],
#
#        ...,
#
#        [[  8, 220, 173],
#         [ 35, 224, 183],
#         [  0, 218, 168],
#         ...,
#         [186,  38, 231],
#         [187,  41, 231],
#         [187,  41, 231]],
#
#        [[  7, 220, 173],
#         [ 30, 223, 181],
#         [  0, 218, 168],
#         ...,
#         [188,  43, 231],
#         [187,  43, 231],
#         [187,  41, 231]],
#
#        [[  0, 219, 171],
#         [  0, 219, 171],
#         [  0, 218, 169],
#         ...,
#         [198,  75, 235],
#         [201,  87, 236],
#         [186,  38, 231]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 22. ),
#        ('hnieh_E71', 'E71', 'hnieh', None, 'Female', datetime.date(2017, 11, 20), array([[[ 36,  33,  33],
#         [147, 145, 145],
#         [ 23,  20,  20],
#         ...,
#         [243, 151,  28],
#         [254, 246, 237],
#         [255, 255, 255]],
#
#        [[ 32,  29,  29],
#         [116, 114, 114],
#         [ 20,  17,  17],
#         ...,
#         [242, 139,   1],
#         [252, 231, 204],
#         [255, 255, 255]],
#
#        [[ 33,  30,  30],
#         [ 82,  80,  80],
#         [ 20,  16,  16],
#         ...,
#         [242, 138,   0],
#         [252, 223, 186],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [113, 111, 111],
#         [ 12,   8,   8],
#         ...,
#         [245, 169,  68],
#         [241, 134,   0],
#         [248, 197, 128]],
#
#        [[255, 255, 255],
#         [140, 139, 139],
#         [ 14,  11,  11],
#         ...,
#         [246, 178,  85],
#         [241, 134,   0],
#         [248, 196, 127]],
#
#        [[255, 255, 255],
#         [184, 182, 182],
#         [ 16,  13,  13],
#         ...,
#         [248, 194, 122],
#         [241, 133,   0],
#         [249, 204, 143]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 24. ),
#        ('hnieh_E74', 'E74', 'hnieh', None, 'Male', datetime.date(2017, 12, 13), array([[[248, 224, 184],
#         [252, 251, 249],
#         [252, 249, 245],
#         ...,
#         [247, 183, 182],
#         [250, 228, 227],
#         [251, 252, 252]],
#
#        [[240, 164,  39],
#         [254, 251, 245],
#         [252, 241, 220],
#         ...,
#         [237,  47,  42],
#         [246, 146, 144],
#         [254, 255, 255]],
#
#        [[240, 167,  46],
#         [254, 251, 245],
#         [252, 241, 221],
#         ...,
#         [236,  34,  29],
#         [240,  81,  78],
#         [253, 253, 253]],
#
#        ...,
#
#        [[242, 183,  84],
#         [236, 149,   1],
#         [237, 152,  10],
#         ...,
#         [235,  21,  16],
#         [235,  17,  12],
#         [237,  69,  65]],
#
#        [[242, 182,  81],
#         [236, 149,   2],
#         [237, 151,   8],
#         ...,
#         [234,  14,   8],
#         [235,  14,   8],
#         [237,  66,  62]],
#
#        [[245, 196, 114],
#         [242, 179,  74],
#         [241, 175,  65],
#         ...,
#         [247, 162, 160],
#         [239,  67,  64],
#         [239,  96,  93]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 30. ),
#        ('hnieh_E75', 'E75', 'hnieh', None, 'Male', datetime.date(2017, 12, 13), array([[[247, 132,  90],
#         [246, 111,  61],
#         [252, 237, 232],
#         ...,
#         [253, 253, 253],
#         [180, 216, 181],
#         [115, 183, 116]],
#
#        [[247,  70,   6],
#         [251, 158, 124],
#         [252, 187, 163],
#         ...,
#         [255, 255, 255],
#         [ 80, 167,  81],
#         [ 48, 150,  50]],
#
#        [[247,  74,  11],
#         [251, 176, 149],
#         [250, 140, 100],
#         ...,
#         [223, 239, 223],
#         [ 28, 141,  30],
#         [115, 184, 116]],
#
#        ...,
#
#        [[247,  80,  19],
#         [249, 123,  76],
#         [247,  71,   7],
#         ...,
#         [224, 239, 224],
#         [140, 197, 141],
#         [190, 221, 191]],
#
#        [[247,  76,  14],
#         [248,  89,  32],
#         [249, 106,  54],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[249, 123,  77],
#         [248,  88,  29],
#         [247,  78,  16],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [253, 253, 253]]], dtype=uint8), 'vivarium', '1910', 'Thy1-GP5.3', '', 35. ),
#        ('hnieh_E76', 'E76', 'hnieh', None, 'Male', datetime.date(2018, 3, 25), array([[[182, 225, 181],
#         [251, 252, 251],
#         [255, 255, 255],
#         ...,
#         [237, 237, 109],
#         [250, 250, 229],
#         [251, 251, 252]],
#
#        [[ 39, 171,  34],
#         [204, 235, 203],
#         [185, 228, 184],
#         ...,
#         [227, 228,   0],
#         [251, 251, 213],
#         [253, 253, 255]],
#
#        [[ 52, 175,  47],
#         [157, 216, 155],
#         [ 26, 165,  21],
#         ...,
#         [227, 228,   4],
#         [251, 251, 214],
#         [253, 253, 255]],
#
#        ...,
#
#        [[ 13, 160,   7],
#         [155, 215, 152],
#         [ 79, 186,  75],
#         ...,
#         [229, 230,  17],
#         [229, 230,  15],
#         [248, 248, 212]],
#
#        [[ 15, 161,  10],
#         [ 45, 173,  41],
#         [ 64, 180,  59],
#         ...,
#         [227, 228,   5],
#         [229, 230,  13],
#         [249, 249, 218]],
#
#        [[ 95, 192,  92],
#         [  2, 155,   0],
#         [ 14, 160,   8],
#         ...,
#         [241, 241, 128],
#         [250, 251, 213],
#         [253, 253, 251]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 27.4),
#        ('hnieh_E77', 'E77', 'hnieh', None, 'Female', datetime.date(2017, 11, 8), array([[[253, 253, 253],
#         [228, 228, 228],
#         [196, 195, 195],
#         ...,
#         [239, 173,  64],
#         [251, 245, 234],
#         [251, 252, 252]],
#
#        [[255, 255, 255],
#         [181, 180, 180],
#         [ 75,  73,  73],
#         ...,
#         [236, 146,   0],
#         [252, 235, 206],
#         [253, 255, 255]],
#
#        [[255, 255, 255],
#         [184, 183, 183],
#         [ 77,  75,  75],
#         ...,
#         [236, 146,   0],
#         [250, 226, 185],
#         [253, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [122, 121, 121],
#         ...,
#         [236, 146,   0],
#         [250, 225, 184],
#         [253, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [139, 138, 138],
#         ...,
#         [236, 145,   0],
#         [250, 224, 182],
#         [253, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [180, 179, 179],
#         ...,
#         [237, 155,  18],
#         [252, 235, 207],
#         [253, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Ai93-Emx1', '', 33. ),
#        ('hnieh_E78', 'E78', 'hnieh', None, 'Female', datetime.date(2017, 11, 8), array([[[239, 159, 234],
#         [239, 160, 234],
#         [249, 238, 248],
#         ...,
#         [251, 251, 251],
#         [251, 251, 251],
#         [248, 248, 248]],
#
#        [[237, 107, 228],
#         [245, 174, 240],
#         [254, 248, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [251, 251, 251]],
#
#        [[236, 104, 228],
#         [248, 198, 245],
#         [254, 248, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [251, 251, 251]],
#
#        ...,
#
#        [[237, 109, 229],
#         [250, 211, 247],
#         [254, 252, 254],
#         ...,
#         [135, 134, 134],
#         [ 80,  78,  78],
#         [255, 255, 255]],
#
#        [[237, 116, 231],
#         [249, 199, 245],
#         [252, 228, 250],
#         ...,
#         [167, 166, 166],
#         [ 74,  72,  72],
#         [249, 249, 249]],
#
#        [[242, 153, 237],
#         [237, 112, 230],
#         [238, 114, 230],
#         ...,
#         [217, 217, 217],
#         [ 36,  33,  33],
#         [180, 178, 178]]], dtype=uint8), 'vivarium', '1910', 'Ai93-Emx1', '', 30.6),
#        ('hnieh_E79', 'E79', 'hnieh', None, 'Male', datetime.date(2017, 5, 3), array([[[ 88,  81, 249],
#         [157, 153, 251],
#         [255, 255, 253],
#         ...,
#         [253, 253, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        [[ 20,  11, 250],
#         [ 41,  33, 251],
#         [234, 234, 255],
#         ...,
#         [255, 255, 255],
#         [179, 176, 254],
#         [203, 201, 252]],
#
#        [[ 55,  48, 251],
#         [ 98,  92, 252],
#         [116, 113, 252],
#         ...,
#         [251, 251, 255],
#         [ 42,  34, 251],
#         [146, 142, 251]],
#
#        ...,
#
#        [[ 56,  49, 251],
#         [133, 129, 252],
#         [ 50,  42, 251],
#         ...,
#         [ 22,  13, 250],
#         [236, 236, 255],
#         [255, 255, 253]],
#
#        [[ 50,  43, 251],
#         [119, 114, 252],
#         [ 99,  93, 252],
#         ...,
#         [ 18,  10, 250],
#         [235, 234, 255],
#         [255, 255, 253]],
#
#        [[ 60,  53, 251],
#         [ 20,  13, 250],
#         [ 26,  18, 250],
#         ...,
#         [103,  98, 252],
#         [246, 246, 255],
#         [254, 254, 253]]], dtype=uint8), 'vivarium', '1910', 'C57BL6/J', '', 36.6),
#        ('hnieh_E80', 'E80', 'hnieh', None, 'Male', None, array([[[247, 190, 104],
#         [252, 242, 227],
#         [249, 210, 150],
#         ...,
# ...
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'C57BL6/J', '', 19. ),
#        ('testuser_T06', 'T06', 'testuser', None, 'Male', datetime.date(2019, 1, 13), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'D1-CRE', '', 25. ),
#        ('testuser_T07', 'T07', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'VGAT-ChR2-EYFP', '', 19. ),
#        ('testuser_T08', 'T08', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'D2-CRE', '', 19. ),
#        ('testuser_T09', 'T09', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'DAT-IRES-CRE', '', 24. ),
#        ('testuser_T10', 'T10', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'C57BL6/J', '', 22. ),
#        ('testuser_T12', 'T12', 'testuser', None, 'Male', datetime.date(2019, 2, 10), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'DAT-Ai148', '', 19. ),
#        ('testuser_T13', 'T13', 'testuser', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'vivarium', '1910', 'Unknown', '', 26. ),
#        ('testuser_T14', 'T14', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'Unknown', '', 26. ),
#        ('testuser_T15', 'T15', 'testuser', None, 'Male', None, array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'Unknown', '', 26. ),
#        ('testuser_T17', 'T17', 'testuser', None, 'Male', datetime.date(2017, 5, 5), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'D1-CRE', '', 23. ),
#        ('testuser_T18', 'T18', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'Unknown', '', 25. ),
#        ('testuser_T19', 'T19', 'testuser', None, 'Male', datetime.date(2017, 4, 4), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'Unknown', '', 25. ),
#        ('testuser_T20', 'T20', 'testuser', None, 'Male', datetime.date(2019, 1, 23), array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), 'valhalla', '1910', 'Unknown', '', 28. ),
#        ('zhihaoz_zz24', 'zz24', 'zhihaoz', None, 'Male', None, None, 'vivarium', '1910', 'Unknown', '', 24.2),
#        ('zhihaoz_zz25', 'zz25', 'zhihaoz', None, 'Male', None, None, 'vivarium', '1910', 'Unknown', '', 23.7),
#        ('zhihaoz_ZZ41', 'ZZ41', 'zhihaoz', None, 'Male', None, None, 'vivarium', '1910', 'Unknown', '', 23.6)],
#       dtype=[('subject_fullname', 'O'), ('subject_nickname', 'O'), ('user_id', 'O'), ('genomics_id', 'O'), ('sex', 'O'), ('dob', 'O'), ('head_plate_mark', 'O'), ('location', 'O'), ('protocol', 'O'), ('line', 'O'), ('subject_description', 'O'), ('initial_weight', '<f8')])

# %%
subjs['subject_fullname']
# Out:
# array(['emanuele_B205', 'emanuele_B208', 'emanuele_B3151',
#        'emanuele_B4486', 'emanuele_B4487', 'emanuele_B4488',
#        'emanuele_B4489', 'hnieh_E18', 'hnieh_E26', 'hnieh_E36',
#        'hnieh_E38', 'hnieh_E39', 'hnieh_E42', 'hnieh_E43', 'hnieh_E44',
#        'hnieh_E45', 'hnieh_E47', 'hnieh_E48', 'hnieh_E49', 'hnieh_E50',
#        'hnieh_E51', 'hnieh_E52', 'hnieh_E53', 'hnieh_E54', 'hnieh_E55',
#        'hnieh_E56', 'hnieh_E57', 'hnieh_E58', 'hnieh_E59', 'hnieh_E61',
#        'hnieh_E62', 'hnieh_E63', 'hnieh_E64', 'hnieh_E65', 'hnieh_E66',
#        'hnieh_E67', 'hnieh_E68', 'hnieh_E69', 'hnieh_E70', 'hnieh_E71',
#        'hnieh_E74', 'hnieh_E75', 'hnieh_E76', 'hnieh_E77', 'hnieh_E78',
#        'hnieh_E79', 'hnieh_E80', 'hnieh_E82', 'hnieh_E83', 'hnieh_E84',
#        'hnieh_E85', 'hnieh_E86', 'hnieh_E87', 'hnieh_E88', 'hnieh_J131',
#        'hnieh_J132', 'hnieh_J133', 'koay_E30', 'koay_E34', 'koay_E35',
#        'koay_K52', 'koay_K55', 'koay_K58', 'koay_K59', 'koay_K60',
#        'koay_K61', 'koay_K62', 'koay_K63', 'koay_K64', 'koay_K65',
#        'koay_K66', 'koay_K67', 'koay_K68', 'koay_kp1', 'koay_KP2',
#        'koay_KP3', 'lpinto_ai10', 'lpinto_ai11', 'lpinto_ai12',
#        'lpinto_ai13', 'lpinto_ai7', 'lpinto_ai8', 'lpinto_ai9',
#        'lpinto_GP1', 'lpinto_GP2', 'lpinto_GP3', 'lpinto_GP4',
#        'lpinto_GP5', 'lpinto_GP6', 'lpinto_SL1', 'lpinto_SL2',
#        'lpinto_SL3', 'lpinto_SL4', 'lpinto_SL5', 'lpinto_SL6',
#        'lpinto_SL7', 'lpinto_SP1', 'lpinto_SP10', 'lpinto_SP11',
#        'lpinto_SP12', 'lpinto_SP13', 'lpinto_SP14', 'lpinto_SP2',
#        'lpinto_SP3', 'lpinto_SP4', 'lpinto_SP5', 'lpinto_SP6',
#        'lpinto_SP7', 'lpinto_SP8', 'lpinto_SP9', 'lpinto_vg1',
#        'lpinto_vg12', 'lpinto_vg15', 'lpinto_vg16', 'lpinto_vg17',
#        'lpinto_vg18', 'lpinto_vg20', 'lpinto_vg21', 'lpinto_vg22',
#        'lpinto_vg23', 'lpinto_vg24', 'lpinto_vg25', 'lpinto_vg26',
#        'lpinto_vg27', 'lpinto_vg28', 'lpinto_vg29', 'lpinto_vg3',
#        'lpinto_vg30', 'lpinto_vg31', 'lpinto_vg32', 'lpinto_vg33',
#        'lpinto_vg34', 'lpinto_vg36', 'lpinto_vg37', 'lpinto_vg38',
#        'lpinto_VG39', 'lpinto_VG40', 'lpinto_VG41', 'lpinto_VG42',
#        'lpinto_VG43', 'lpinto_VG44', 'lpinto_VG45', 'lpinto_VG46',
#        'lpinto_VG47', 'lpinto_VG48', 'lpinto_VG49', 'lpinto_VG50',
#        'lpinto_VG51', 'lpinto_VG52', 'lpinto_VG53', 'mioffe_M10',
#        'mioffe_M10_604', 'mioffe_M11_605', 'mioffe_M12_602', 'mioffe_m13',
#        'mioffe_m14', 'mioffe_m16', 'mioffe_m17', 'mioffe_m18',
#        'mioffe_m19_203', 'mioffe_m20_200', 'mioffe_m21_202',
#        'mioffe_M2_960', 'mioffe_M3_981', 'mioffe_M4_984', 'mioffe_M5_696',
#        'mioffe_M6_672', 'mioffe_M7_669', 'mioffe_M7_669_2',
#        'mioffe_M8_689', 'mioffe_M9_698', 'testuser_T01', 'testuser_T02',
#        'testuser_T03', 'testuser_T05', 'testuser_T06', 'testuser_T07',
#        'testuser_T08', 'testuser_T09', 'testuser_T10', 'testuser_T12',
#        'testuser_T13', 'testuser_T14', 'testuser_T15', 'testuser_T17',
#        'testuser_T18', 'testuser_T19', 'testuser_T20', 'zhihaoz_zz24',
#        'zhihaoz_zz25', 'zhihaoz_ZZ41'], dtype=object)

# %%
subjs['dob']
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, datetime.date(2016, 11, 14), None,
#        datetime.date(2017, 7, 27), datetime.date(2017, 7, 27),
#        datetime.date(2017, 4, 2), datetime.date(2017, 7, 27),
#        datetime.date(2017, 7, 27), datetime.date(2017, 6, 15),
#        datetime.date(2017, 11, 20), datetime.date(2018, 1, 18),
#        datetime.date(2018, 1, 18), datetime.date(2017, 11, 20),
#        datetime.date(2017, 11, 20), datetime.date(2017, 12, 13),
#        datetime.date(2017, 12, 13), datetime.date(2018, 3, 25),
#        datetime.date(2017, 11, 8), datetime.date(2017, 11, 8),
#        datetime.date(2017, 5, 3), None, datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 24), datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 8), None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None,
#        datetime.date(2017, 11, 8), datetime.date(2017, 11, 8),
#        datetime.date(2017, 11, 6), datetime.date(2017, 11, 8),
#        datetime.date(2017, 1, 3), datetime.date(2017, 1, 3),
#        datetime.date(2017, 11, 8), datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 24), datetime.date(2018, 10, 22),
#        datetime.date(2018, 10, 22), datetime.date(2018, 10, 28),
#        datetime.date(2018, 10, 28), datetime.date(2017, 10, 26), None,
#        None, None, None, datetime.date(2017, 12, 23),
#        datetime.date(2017, 12, 23), datetime.date(2019, 3, 27),
#        datetime.date(2019, 9, 2), datetime.date(2019, 9, 2),
#        datetime.date(2019, 8, 17), datetime.date(2019, 8, 17),
#        datetime.date(2019, 8, 17), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 8, 29), None, None, None, None, None, None,
#        None, None, None, None, datetime.date(2017, 8, 9),
#        datetime.date(2017, 8, 9), datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), None, datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), None, None, None,
#        datetime.date(2018, 4, 20), datetime.date(2018, 4, 20),
#        datetime.date(2018, 4, 20), datetime.date(2018, 11, 23),
#        datetime.date(2018, 11, 23), datetime.date(2018, 11, 23),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21), None,
#        datetime.date(2019, 2, 10), None, None, None, None, None, None,
#        None, None, None, None, datetime.date(2018, 10, 11), None,
#        datetime.date(2018, 10, 27), datetime.date(2019, 1, 21), None,
#        datetime.date(2019, 1, 5), None, datetime.date(2019, 1, 22), None,
#        datetime.date(2019, 1, 23), datetime.date(2019, 1, 25),
#        datetime.date(2019, 2, 1), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 13), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 23), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 23), datetime.date(2019, 2, 10), None,
#        datetime.date(2019, 1, 23), None, datetime.date(2017, 5, 5),
#        datetime.date(2019, 1, 23), datetime.date(2017, 4, 4),
#        datetime.date(2019, 1, 23), None, None, None], dtype=object)

# %%
# fetch as a list of dictionaries
subjs_dict = subject.Subject.fetch(as_dict=True)
subjs_dict
# Out:
# [{'subject_fullname': 'emanuele_B205',
#   'subject_nickname': 'B205',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [246, 251, 252],
#           [193, 241, 251],
#           ...,
#           [ 64, 215, 246],
#           [105, 224, 248],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [239, 252, 254],
#           [ 60, 217, 249],
#           ...,
#           [ 34, 212, 248],
#           [ 58, 217, 249],
#           [254, 253, 253]],
#
#          [[254, 255, 255],
#           [172, 239, 252],
#           [ 55, 216, 249],
#           ...,
#           [ 64, 218, 249],
#           [ 37, 212, 248],
#           [142, 231, 249]],
#
#          ...,
#
#          [[175, 239, 252],
#           [  0, 202, 247],
#           [ 40, 213, 248],
#           ...,
#           [ 13, 207, 247],
#           [ 78, 221, 250],
#           [255, 254, 253]],
#
#          [[197, 244, 253],
#           [  0, 202, 247],
#           [ 78, 220, 249],
#           ...,
#           [  3, 205, 247],
#           [ 86, 222, 250],
#           [255, 254, 253]],
#
#          [[232, 250, 254],
#           [ 30, 210, 248],
#           [149, 234, 252],
#           ...,
#           [ 20, 208, 248],
#           [157, 236, 252],
#           [255, 255, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B208',
#   'subject_nickname': 'B208',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[252, 252, 252],
#           [245, 214, 208],
#           [251, 246, 245],
#           ...,
#           [252, 250, 250],
#           [245, 210, 203],
#           [250, 246, 245]],
#
#          [[255, 253, 253],
#           [225,  90,  63],
#           [242, 183, 171],
#           ...,
#           [249, 223, 218],
#           [221,  69,  39],
#           [247, 223, 217]],
#
#          [[254, 251, 249],
#           [224,  86,  58],
#           [234, 138, 119],
#           ...,
#           [229, 111,  88],
#           [219,  59,  27],
#           [243, 200, 191]],
#
#          ...,
#
#          [[246, 202, 193],
#           [218,  54,  21],
#           [218,  54,  21],
#           ...,
#           [217,  50,  17],
#           [240, 171, 157],
#           [252, 245, 243]],
#
#          [[250, 224, 219],
#           [222,  78,  49],
#           [217,  49,  16],
#           ...,
#           [221,  73,  43],
#           [245, 198, 188],
#           [254, 255, 255]],
#
#          [[255, 255, 255],
#           [235, 144, 125],
#           [223,  83,  55],
#           ...,
#           [229, 115,  92],
#           [247, 212, 205],
#           [254, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B3151',
#   'subject_nickname': 'B3151',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [254, 253, 253],
#           [255, 253, 255],
#           ...,
#           [152, 250, 177],
#           [119, 250, 153],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [251, 255, 252],
#           [218, 254, 228],
#           ...,
#           [ 87, 251, 129],
#           [ 28, 250,  85],
#           [250, 253, 251]],
#
#          [[255, 255, 255],
#           [169, 253, 191],
#           [ 17, 249,  69],
#           ...,
#           [ 82, 251, 126],
#           [ 35, 250,  91],
#           [250, 253, 251]],
#
#          ...,
#
#          [[ 15, 249,  75],
#           [  0, 249,  56],
#           [ 76, 251, 121],
#           ...,
#           [ 83, 251, 126],
#           [ 71, 251, 117],
#           [ 43, 248,  96]],
#
#          [[ 12, 249,  72],
#           [  0, 249,  55],
#           [ 94, 251, 134],
#           ...,
#           [254, 255, 255],
#           [126, 252, 158],
#           [ 37, 248,  91]],
#
#          [[ 50, 250, 101],
#           [  5, 249,  60],
#           [151, 252, 177],
#           ...,
#           [255, 255, 255],
#           [186, 254, 204],
#           [ 87, 249, 128]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B4486',
#   'subject_nickname': 'B4486',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[252, 251, 251],
#           [252, 248, 248],
#           [247, 195, 193],
#           ...,
#           [252, 252, 252],
#           [252, 241, 241],
#           [246, 193, 191]],
#
#          [[252, 218, 217],
#           [243, 117, 112],
#           [246, 154, 150],
#           ...,
#           [253, 236, 236],
#           [253, 227, 226],
#           [237,  72,  66]],
#
#          [[251, 211, 210],
#           [241,  91,  86],
#           [246, 145, 141],
#           ...,
#           [244, 131, 127],
#           [248, 177, 174],
#           [238,  82,  76]],
#
#          ...,
#
#          [[255, 252, 252],
#           [238,  65,  59],
#           [235,  26,  18],
#           ...,
#           [249, 182, 180],
#           [249, 185, 182],
#           [237,  65,  58]],
#
#          [[255, 252, 252],
#           [238,  60,  54],
#           [235,  28,  21],
#           ...,
#           [255, 255, 255],
#           [252, 219, 218],
#           [241, 123, 119]],
#
#          [[255, 254, 254],
#           [242, 102,  97],
#           [244, 135, 132],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B4487',
#   'subject_nickname': 'B4487',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[210, 210, 210],
#           [115, 115, 115],
#           [215, 215, 215],
#           ...,
#           [253, 253, 253],
#           [254, 254, 254],
#           [255, 255, 255]],
#
#          [[104, 104, 104],
#           [ 37,  37,  37],
#           [141, 141, 141],
#           ...,
#           [255, 255, 255],
#           [247, 247, 247],
#           [214, 214, 214]],
#
#          [[ 12,  12,  12],
#           [ 50,  50,  50],
#           [120, 120, 120],
#           ...,
#           [194, 194, 194],
#           [209, 209, 209],
#           [ 59,  59,  59]],
#
#          ...,
#
#          [[ 99,  99,  99],
#           [124, 124, 124],
#           [ 50,  50,  50],
#           ...,
#           [ 43,  43,  43],
#           [168, 168, 168],
#           [ 70,  70,  70]],
#
#          [[117, 117, 117],
#           [110, 110, 110],
#           [ 74,  74,  74],
#           ...,
#           [ 47,  47,  47],
#           [200, 200, 200],
#           [216, 216, 216]],
#
#          [[195, 195, 195],
#           [192, 192, 192],
#           [177, 177, 177],
#           ...,
#           [162, 162, 162],
#           [234, 234, 234],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B4488',
#   'subject_nickname': 'B4488',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [215, 172, 247],
#           [166,  70, 239],
#           ...,
#           [251, 249, 252],
#           [180, 100, 241],
#           [200, 143, 243]],
#
#          [[255, 255, 255],
#           [189, 115, 245],
#           [136,   3, 236],
#           ...,
#           [242, 228, 253],
#           [144,  20, 238],
#           [161,  58, 238]],
#
#          [[255, 255, 255],
#           [191, 119, 245],
#           [139,   9, 236],
#           ...,
#           [221, 183, 250],
#           [139,   8, 236],
#           [164,  65, 238]],
#
#          ...,
#
#          [[155,  43, 239],
#           [142,  15, 237],
#           [139,  10, 236],
#           ...,
#           [176,  89, 242],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[144,  22, 237],
#           [142,  16, 237],
#           [138,   7, 236],
#           ...,
#           [174,  85, 242],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[196, 131, 246],
#           [165,  64, 240],
#           [177,  89, 242],
#           ...,
#           [192, 121, 245],
#           [255, 255, 255],
#           [253, 253, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'emanuele_B4489',
#   'subject_nickname': 'B4489',
#   'user_id': 'emanuele',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [243, 244, 249],
#           ...,
#           [ 81,  98, 186],
#           [216, 220, 239],
#           [187, 193, 226]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [222, 226, 243],
#           ...,
#           [  7,  31, 159],
#           [151, 162, 215],
#           [ 50,  70, 175]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [220, 224, 242],
#           ...,
#           [ 15,  39, 162],
#           [ 98, 113, 194],
#           [ 48,  68, 174]],
#
#          ...,
#
#          [[255, 255, 255],
#           [103, 118, 196],
#           [ 52,  72, 177],
#           ...,
#           [  9,  32, 159],
#           [ 92, 108, 192],
#           [ 68,  87, 182]],
#
#          [[255, 255, 255],
#           [100, 115, 195],
#           [ 49,  69, 176],
#           ...,
#           [104, 119, 197],
#           [ 27,  50, 167],
#           [ 49,  69, 174]],
#
#          [[255, 255, 255],
#           [135, 147, 209],
#           [ 84, 101, 189],
#           ...,
#           [179, 186, 225],
#           [132, 144, 208],
#           [ 79,  96, 186]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E18',
#   'subject_nickname': 'E18',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'hnieh_E26',
#   'subject_nickname': 'E26',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [253, 250, 248],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [247, 239, 229],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 24.0},
#  {'subject_fullname': 'hnieh_E36',
#   'subject_nickname': 'E36',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 23.0},
#  {'subject_fullname': 'hnieh_E38',
#   'subject_nickname': 'E38',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[193, 165, 227],
#           [236, 229, 245],
#           [252, 252, 252],
#           ...,
#           [249, 249, 249],
#           [ 85,  85,  85],
#           [119, 118, 118]],
#
#          [[ 89,  10, 186],
#           [185, 152, 226],
#           [255, 255, 255],
#           ...,
#           [247, 247, 247],
#           [ 28,  27,  27],
#           [ 39,  38,  38]],
#
#          [[ 94,  19, 189],
#           [153, 104, 213],
#           [255, 255, 255],
#           ...,
#           [242, 242, 242],
#           [ 36,  35,  35],
#           [ 19,  18,  18]],
#
#          ...,
#
#          [[247, 243, 252],
#           [116,  51, 198],
#           [ 99,  26, 191],
#           ...,
#           [255, 255, 255],
#           [146, 146, 146],
#           [  6,   5,   5]],
#
#          [[247, 243, 252],
#           [115,  48, 197],
#           [117,  51, 198],
#           ...,
#           [255, 255, 255],
#           [138, 137, 137],
#           [  1,   0,   0]],
#
#          [[251, 249, 254],
#           [132,  74, 204],
#           [193, 164, 229],
#           ...,
#           [255, 255, 255],
#           [ 78,  78,  78],
#           [ 65,  65,  65]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'hnieh_E39',
#   'subject_nickname': 'E39',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[ 34,  35, 255],
#           [151, 152, 255],
#           [ 36,  37, 255],
#           ...,
#           [122, 255, 105],
#           [251, 255, 251],
#           [ 90, 255,  69]],
#
#          [[ 12,  13, 255],
#           [ 27,  28, 255],
#           [ 48,  49, 255],
#           ...,
#           [ 65, 255,  41],
#           [238, 255, 237],
#           [ 64, 255,  39]],
#
#          [[ 15,  16, 255],
#           [  0,   0, 255],
#           [ 31,  31, 255],
#           ...,
#           [ 41, 255,  13],
#           [210, 255, 204],
#           [ 61, 255,  36]],
#
#          ...,
#
#          [[135, 135, 255],
#           [ 25,  26, 255],
#           [ 93,  94, 255],
#           ...,
#           [143, 255, 128],
#           [ 88, 255,  66],
#           [ 72, 255,  48]],
#
#          [[136, 136, 255],
#           [ 14,  15, 255],
#           [112, 112, 255],
#           ...,
#           [119, 255, 102],
#           [131, 255, 115],
#           [ 72, 255,  49]],
#
#          [[181, 181, 255],
#           [  5,   5, 255],
#           [146, 147, 255],
#           ...,
#           [216, 255, 211],
#           [218, 255, 213],
#           [ 93, 255,  72]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'hnieh_E42',
#   'subject_nickname': 'E42',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E43',
#   'subject_nickname': 'E43',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[192, 190, 188],
#           [252, 252, 252],
#           [255, 255, 255],
#           ...,
#           [254, 229, 228],
#           [253, 182, 179],
#           [255, 255, 255]],
#
#          [[ 48,  42,  34],
#           [240, 240, 239],
#           [255, 255, 255],
#           ...,
#           [253, 184, 181],
#           [249,  40,  31],
#           [255, 248, 248]],
#
#          ...,
#
#          [[225, 224, 223],
#           [ 22,  15,   6],
#           [ 32,  26,  17],
#           ...,
#           [252, 152, 148],
#           [248,  15,   5],
#           [255, 239, 239]],
#
#          [[222, 221, 219],
#           [ 46,  40,  32],
#           [104,  99,  94],
#           ...,
#           [254, 216, 214],
#           [252, 142, 137],
#           [255, 255, 254]],
#
#          [[220, 219, 217],
#           [100,  96,  90],
#           [233, 233, 232],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 21.0},
#  {'subject_fullname': 'hnieh_E44',
#   'subject_nickname': 'E44',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [175, 174, 172]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [241, 241, 241],
#           [204, 204, 202],
#           [ 42,  40,  35]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [165, 164, 162],
#           [ 88,  86,  83],
#           [ 57,  54,  50]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [168, 167, 165],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [222, 222, 221],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 21.0},
#  {'subject_fullname': 'hnieh_E45',
#   'subject_nickname': 'E45',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [249,  55,  47],
#           [248,  18,  12],
#           [254, 210, 209]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [248,  20,  11],
#           [248,   0,   0],
#           [252, 157, 153]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [248,  22,  13],
#           [248,   1,   0],
#           [250, 100,  94]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [250,  78,  71],
#           [252, 142, 138],
#           [249,  60,  52]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [250,  72,  64],
#           [252, 164, 161],
#           [249,  56,  48]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [250,  73,  66],
#           [253, 199, 197],
#           [250,  83,  76]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 30.7},
#  {'subject_fullname': 'hnieh_E47',
#   'subject_nickname': 'E47',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
#           [253, 253, 253],
#           [253, 253, 253],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 254, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E48',
#   'subject_nickname': 'E48',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
#           [253, 253, 253],
#           [253, 253, 253],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E49',
#   'subject_nickname': 'E49',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
#           [253, 253, 253],
#           [253, 253, 253],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E50',
#   'subject_nickname': 'E50',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': None,
#   'head_plate_mark': array([[[113,   6, 243],
#           [149,  69, 245],
#           [253, 252, 253],
#           ...,
#           [  0, 238,  16],
#           [ 92, 244, 110],
#           [255, 253, 255]],
#
#          [[114,   8, 243],
#           [114,   8, 243],
#           [171, 108, 248],
#           ...,
#           [136, 248, 149],
#           [  8, 240,  34],
#           [230, 252, 233]],
#
#          [[115,   9, 243],
#           [115,   8, 243],
#           [112,   4, 243],
#           ...,
#           [176, 250, 185],
#           [ 19, 240,  44],
#           [117, 245, 131]],
#
#          ...,
#
#          [[117,  12, 243],
#           [113,   6, 243],
#           [114,   8, 243],
#           ...,
#           [181, 250, 189],
#           [  0, 238,  19],
#           [  0, 239,  20]],
#
#          [[115,   8, 243],
#           [118,  14, 243],
#           [152,  74, 246],
#           ...,
#           [123, 247, 137],
#           [ 11, 239,  33],
#           [ 81, 243, 100]],
#
#          [[116,  10, 243],
#           [212, 180, 251],
#           [246, 240, 254],
#           ...,
#           [  0, 238,  20],
#           [ 94, 245, 112],
#           [255, 254, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 21.0},
#  {'subject_fullname': 'hnieh_E51',
#   'subject_nickname': 'E51',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': None,
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
#           [253, 253, 253],
#           [253, 253, 253],
#           [251, 251, 251]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [253, 253, 253]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 21.0},
#  {'subject_fullname': 'hnieh_E52',
#   'subject_nickname': 'E52',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[252, 252, 252],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [252, 252, 252],
#           [221, 221, 221],
#           [174, 174, 174]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [139, 139, 139],
#           [  0,   0,   0]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [111, 111, 111],
#           [  3,   3,   3]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [  0,   0,   0],
#           [  6,   6,   6],
#           [ 13,  13,  13]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 39,  39,  39],
#           [  4,   4,   4],
#           [  9,   9,   9]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [151, 151, 151],
#           [  0,   0,   0],
#           [ 53,  53,  53]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 28.0},
#  {'subject_fullname': 'hnieh_E53',
#   'subject_nickname': 'E53',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[252, 252, 252],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [142,  16, 233],
#           [198, 138, 242],
#           [252, 253, 250]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [138,   8, 233],
#           [170,  76, 240],
#           [253, 255, 252]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [140,  12, 233],
#           [172,  80, 240],
#           [253, 255, 252]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [152,  38, 235],
#           [201, 141, 245],
#           [147,  29, 234]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [151,  37, 235],
#           [175,  85, 240],
#           [147,  29, 234]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [176,  89, 240],
#           [138,   9, 233],
#           [164,  67, 236]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'hnieh_E54',
#   'subject_nickname': 'E54',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Ai93-Emx1',
#   'subject_description': '',
#   'initial_weight': 27.0},
#  {'subject_fullname': 'hnieh_E55',
#   'subject_nickname': 'E55',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [254, 255, 254],
#           [194, 245, 184],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [231, 238,  78],
#           [242, 246, 160],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [236, 242, 113],
#           [255, 255, 252],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 28.0},
#  {'subject_fullname': 'hnieh_E56',
#   'subject_nickname': 'E56',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 254],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [254, 253, 241],
#           [242, 233, 111],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 254],
#           [252, 248, 216],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 254],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 28.0},
#  {'subject_fullname': 'hnieh_E57',
#   'subject_nickname': 'E57',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[252, 252, 252],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [253, 252, 252],
#           [122, 252, 236],
#           [116, 248, 232]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [ 39, 254, 228],
#           [ 37, 251, 224]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [253, 255, 255],
#           [ 29, 253, 226],
#           [ 20, 251, 223]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [126, 254, 238],
#           [  0, 253, 221],
#           [  7, 253, 222]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [168, 254, 243],
#           [  0, 253, 221],
#           [  3, 253, 222]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [221, 255, 251],
#           [ 11, 253, 223],
#           [ 45, 251, 226]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 29.0},
#  {'subject_fullname': 'hnieh_E58',
#   'subject_nickname': 'E58',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2016, 11, 14),
#   'head_plate_mark': None,
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Ai93-Emx1',
#   'subject_description': '',
#   'initial_weight': 28.2},
#  {'subject_fullname': 'hnieh_E59',
#   'subject_nickname': 'E59',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [237, 248, 240],
#           [145, 209, 162],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[249, 253, 251],
#           [158, 215, 173],
#           [ 23, 155,  53],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[221, 242, 226],
#           [ 53, 172,  87],
#           [  0, 148,  39],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[ 54, 173,  89],
#           [181, 225, 194],
#           [ 46, 170,  82],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[222, 242, 228],
#           [223, 242, 228],
#           [ 43, 168,  80],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [232, 246, 236],
#           [ 52, 172,  87],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 28.0},
#  {'subject_fullname': 'hnieh_E61',
#   'subject_nickname': 'E61',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': datetime.date(2017, 7, 27),
#   'head_plate_mark': array([[[247,   3,  56],
#           [249, 100, 109],
#           [255, 243, 245],
#           ...,
#           [245,  10,   9],
#           [245,   9,   9],
#           [245,  12,  12]],
#
#          [[245,  10,  17],
#           [245,  10,   9],
#           [247,  70,  71],
#           ...,
#           [247,  20,  68],
#           [251, 101, 169],
#           [245,  12,  11]],
#
#          [[245,  10,  10],
#           [245,   9,   9],
#           [245,   4,   4],
#           ...,
#           [248,  23,  84],
#           [253, 128, 215],
#           [245,  13,  11]],
#
#          ...,
#
#          [[245,   9,   9],
#           [245,  12,  12],
#           [252, 123, 195],
#           ...,
#           [249, 105, 113],
#           [246,  26,  24],
#           [254, 244, 244]],
#
#          [[245,  10,   9],
#           [245,   6,   0],
#           [250,  52, 135],
#           ...,
#           [254, 222, 226],
#           [251, 160, 159],
#           [255, 254, 254]],
#
#          [[245,  15,  21],
#           [246,  27,  41],
#           [245,   8,   7],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 22.5},
#  {'subject_fullname': 'hnieh_E62',
#   'subject_nickname': 'E62',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': datetime.date(2017, 7, 27),
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [254, 255, 253],
#           ...,
#           [171,  99, 234],
#           [242, 231, 250],
#           [252, 252, 251]],
#
#          [[255, 255, 255],
#           [253, 250, 255],
#           [245, 237, 253],
#           ...,
#           [131,  20, 227],
#           [234, 216, 250],
#           [255, 255, 254]],
#
#          [[255, 255, 255],
#           [232, 211, 249],
#           [170,  95, 236],
#           ...,
#           [135,  28, 228],
#           [227, 202, 249],
#           [223, 195, 246]],
#
#          ...,
#
#          [[136,  30, 228],
#           [148,  52, 231],
#           [201, 153, 243],
#           ...,
#           [154,  63, 232],
#           [215, 178, 246],
#           [162,  80, 232]],
#
#          [[142,  41, 229],
#           [149,  54, 231],
#           [231, 209, 249],
#           ...,
#           [161,  77, 234],
#           [207, 163, 245],
#           [160,  76, 232]],
#
#          [[211, 172, 245],
#           [201, 152, 243],
#           [138,  35, 228],
#           ...,
#           [181, 116, 238],
#           [134,  26, 228],
#           [172, 101, 234]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 23.4},
#  {'subject_fullname': 'hnieh_E63',
#   'subject_nickname': 'E63',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 4, 2),
#   'head_plate_mark': array([[[241,  82, 243],
#           [245, 126, 246],
#           [240,  68, 242],
#           ...,
#           [125, 124, 195],
#           [246, 246, 251],
#           [255, 255, 255]],
#
#          [[240,  70, 242],
#           [242,  86, 244],
#           [240,  63, 242],
#           ...,
#           [116, 115, 190],
#           [245, 245, 250],
#           [255, 255, 255]],
#
#          [[240,  65, 242],
#           [240,  64, 242],
#           [240,  62, 242],
#           ...,
#           [116, 115, 191],
#           [245, 245, 250],
#           [255, 255, 255]],
#
#          ...,
#
#          [[247, 159, 248],
#           [242,  85, 243],
#           [252, 216, 252],
#           ...,
#           [160, 159, 210],
#           [250, 250, 253],
#           [255, 255, 255]],
#
#          [[249, 179, 250],
#           [243,  95, 245],
#           [253, 225, 253],
#           ...,
#           [174, 174, 218],
#           [251, 251, 253],
#           [255, 255, 255]],
#
#          [[250, 188, 250],
#           [244, 107, 245],
#           [253, 234, 253],
#           ...,
#           [239, 239, 248],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Ai93-Emx1',
#   'subject_description': '',
#   'initial_weight': 30.6},
#  {'subject_fullname': 'hnieh_E64',
#   'subject_nickname': 'E64',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 7, 27),
#   'head_plate_mark': array([[[251, 180, 180],
#           [247,   5,   5],
#           [247,   2,   2],
#           ...,
#           [254, 254, 254],
#           [254, 254, 254],
#           [253, 253, 253]],
#
#          [[251, 137, 137],
#           [247,   0,   0],
#           [247,   1,   1],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [254, 254, 254]],
#
#          [[250, 112, 112],
#           [247,   0,   0],
#           [247,   1,   1],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [254, 254, 254]],
#
#          ...,
#
#          [[253, 203, 203],
#           [247,   7,   7],
#           [253, 202, 202],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [254, 254, 254]],
#
#          [[253, 202, 202],
#           [247,   8,   8],
#           [253, 205, 205],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [254, 254, 254]],
#
#          [[253, 209, 209],
#           [247,  25,  25],
#           [253, 207, 207],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [254, 254, 254]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 23.0},
#  {'subject_fullname': 'hnieh_E65',
#   'subject_nickname': 'E65',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 7, 27),
#   'head_plate_mark': array([[[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [200, 172, 221],
#           [158, 107, 196],
#           [252, 252, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [137,  74, 184],
#           [149,  92, 191],
#           [254, 253, 254]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [112,  36, 169],
#           [176, 134, 207],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [251, 248, 252],
#           [125,  55, 176],
#           [153, 100, 193]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [247, 243, 250],
#           [124,  54, 176],
#           [201, 173, 222]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [233, 221, 242],
#           [251, 249, 252]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 25.0},
#  {'subject_fullname': 'hnieh_E66',
#   'subject_nickname': 'E66',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 6, 15),
#   'head_plate_mark': array([[[251, 252, 253],
#           [187, 246, 252],
#           [244, 252, 253],
#           ...,
#           [254, 253, 253],
#           [255, 253, 254],
#           [251, 251, 251]],
#
#          [[249, 254, 255],
#           [ 52, 236, 253],
#           [229, 252, 255],
#           ...,
#           [247, 253, 251],
#           [238, 251, 247],
#           [254, 253, 254]],
#
#          [[250, 254, 255],
#           [ 53, 236, 253],
#           [216, 251, 255],
#           ...,
#           [179, 235, 219],
#           [110, 217, 187],
#           [255, 255, 255]],
#
#          ...,
#
#          [[100, 240, 254],
#           [  0, 230, 253],
#           [135, 244, 254],
#           ...,
#           [162, 231, 211],
#           [101, 215, 183],
#           [255, 255, 255]],
#
#          [[ 51, 236, 253],
#           [  0, 230, 253],
#           [174, 247, 254],
#           ...,
#           [158, 230, 209],
#           [ 95, 213, 180],
#           [255, 255, 255]],
#
#          [[ 57, 236, 253],
#           [ 86, 239, 254],
#           [245, 254, 255],
#           ...,
#           [213, 244, 235],
#           [185, 237, 222],
#           [254, 254, 254]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 28.4},
#  {'subject_fullname': 'hnieh_E67',
#   'subject_nickname': 'E67',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': datetime.date(2017, 11, 20),
#   'head_plate_mark': array([[[163, 236, 225],
#           [114, 227, 211],
#           [250, 252, 252],
#           ...,
#           [253, 253, 253],
#           [240, 241, 252],
#           [187, 192, 247]],
#
#          [[111, 229, 212],
#           [  1, 210, 178],
#           [233, 251, 248],
#           ...,
#           [255, 255, 255],
#           [216, 220, 253],
#           [ 53,  72, 241]],
#
#          [[116, 230, 213],
#           [  2, 209, 177],
#           [195, 244, 236],
#           ...,
#           [211, 216, 252],
#           [216, 220, 253],
#           [ 56,  74, 241]],
#
#          ...,
#
#          [[110, 229, 211],
#           [ 78, 223, 201],
#           [144, 235, 221],
#           ...,
#           [ 88, 103, 245],
#           [ 12,  30, 241],
#           [190, 196, 249]],
#
#          [[103, 228, 209],
#           [135, 233, 219],
#           [255, 255, 255],
#           ...,
#           [170, 178, 250],
#           [  0,  17, 240],
#           [218, 222, 250]],
#
#          [[190, 243, 235],
#           [214, 248, 243],
#           [255, 255, 255],
#           ...,
#           [242, 243, 254],
#           [159, 168, 249],
#           [247, 247, 252]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Ai93-Emx1',
#   'subject_description': '',
#   'initial_weight': 18.6},
#  {'subject_fullname': 'hnieh_E68',
#   'subject_nickname': 'E68',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': datetime.date(2018, 1, 18),
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
#           [ 48,  57, 181],
#           [146, 155, 217],
#           [253, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 28,  46, 179],
#           [ 43,  61, 184],
#           [251, 252, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 14,  34, 174],
#           [ 43,  61, 184],
#           [249, 250, 252]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 31,  50, 180],
#           [ 48,  65, 186],
#           [252, 253, 253]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [  0,  14, 167],
#           [ 92, 106, 200],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 70,  83, 192],
#           [206, 210, 238],
#           [254, 254, 254]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Thy1-GP5.3',
#   'subject_description': '',
#   'initial_weight': 22.2},
#  {'subject_fullname': 'hnieh_E69',
#   'subject_nickname': 'E69',
#   'user_id': 'hnieh',
#   'genomics_id': None,
#   'sex': 'Female',
#   'dob': datetime.date(2018, 1, 18),
#   'head_plate_mark': array([[[253, 253, 253],
#           [253, 253, 253],
#           [253, 253, 253],
#           ...,
# ...
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'D2-CRE',
#   'subject_description': '',
#   'initial_weight': 19.0},
#  {'subject_fullname': 'testuser_T09',
#   'subject_nickname': 'T09',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 1, 23),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-IRES-CRE',
#   'subject_description': '',
#   'initial_weight': 24.0},
#  {'subject_fullname': 'testuser_T10',
#   'subject_nickname': 'T10',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 1, 23),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'C57BL6/J',
#   'subject_description': '',
#   'initial_weight': 22.0},
#  {'subject_fullname': 'testuser_T12',
#   'subject_nickname': 'T12',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 2, 10),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'DAT-Ai148',
#   'subject_description': '',
#   'initial_weight': 19.0},
#  {'subject_fullname': 'testuser_T13',
#   'subject_nickname': 'T13',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'testuser_T14',
#   'subject_nickname': 'T14',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 1, 23),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'testuser_T15',
#   'subject_nickname': 'T15',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 26.0},
#  {'subject_fullname': 'testuser_T17',
#   'subject_nickname': 'T17',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 5, 5),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'D1-CRE',
#   'subject_description': '',
#   'initial_weight': 23.0},
#  {'subject_fullname': 'testuser_T18',
#   'subject_nickname': 'T18',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 1, 23),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 25.0},
#  {'subject_fullname': 'testuser_T19',
#   'subject_nickname': 'T19',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2017, 4, 4),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 25.0},
#  {'subject_fullname': 'testuser_T20',
#   'subject_nickname': 'T20',
#   'user_id': 'testuser',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': datetime.date(2019, 1, 23),
#   'head_plate_mark': array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   'location': 'valhalla',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 28.0},
#  {'subject_fullname': 'zhihaoz_zz24',
#   'subject_nickname': 'zz24',
#   'user_id': 'zhihaoz',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 24.2},
#  {'subject_fullname': 'zhihaoz_zz25',
#   'subject_nickname': 'zz25',
#   'user_id': 'zhihaoz',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 23.7},
#  {'subject_fullname': 'zhihaoz_ZZ41',
#   'subject_nickname': 'ZZ41',
#   'user_id': 'zhihaoz',
#   'genomics_id': None,
#   'sex': 'Male',
#   'dob': None,
#   'head_plate_mark': None,
#   'location': 'vivarium',
#   'protocol': '1910',
#   'line': 'Unknown',
#   'subject_description': '',
#   'initial_weight': 23.6}]

# %%
# fetch as pandas dataframe
subjs_df = subject.Subject.fetch(format='frame')
subjs_df
# Out:
#                  subject_nickname   user_id genomics_id     sex         dob  \
# subject_fullname
# emanuele_B205                B205  emanuele        None    Male        None
# emanuele_B208                B208  emanuele        None    Male        None
# emanuele_B3151              B3151  emanuele        None    Male        None
# emanuele_B4486              B4486  emanuele        None    Male        None
# emanuele_B4487              B4487  emanuele        None    Male        None
# emanuele_B4488              B4488  emanuele        None    Male        None
# emanuele_B4489              B4489  emanuele        None    Male        None
# hnieh_E18                     E18     hnieh        None    Male        None
# hnieh_E26                     E26     hnieh        None    Male        None
# hnieh_E36                     E36     hnieh        None    Male        None
# hnieh_E38                     E38     hnieh        None    Male        None
# hnieh_E39                     E39     hnieh        None    Male        None
# hnieh_E42                     E42     hnieh        None    Male        None
# hnieh_E43                     E43     hnieh        None  Female        None
# hnieh_E44                     E44     hnieh        None  Female        None
# hnieh_E45                     E45     hnieh        None    Male        None
# hnieh_E47                     E47     hnieh        None    Male        None
# hnieh_E48                     E48     hnieh        None    Male        None
# hnieh_E49                     E49     hnieh        None    Male        None
# hnieh_E50                     E50     hnieh        None  Female        None
# hnieh_E51                     E51     hnieh        None  Female        None
# hnieh_E52                     E52     hnieh        None    Male        None
# hnieh_E53                     E53     hnieh        None    Male        None
# hnieh_E54                     E54     hnieh        None    Male        None
# hnieh_E55                     E55     hnieh        None    Male        None
# hnieh_E56                     E56     hnieh        None    Male        None
# hnieh_E57                     E57     hnieh        None    Male        None
# hnieh_E58                     E58     hnieh        None    Male  2016-11-14
# hnieh_E59                     E59     hnieh        None    Male        None
# hnieh_E61                     E61     hnieh        None  Female  2017-07-27
# ...                           ...       ...         ...     ...         ...
# mioffe_m21_202            m21_202    mioffe        None    Male        None
# mioffe_M2_960              M2_960    mioffe        None    Male  2018-10-11
# mioffe_M3_981              M3_981    mioffe        None    Male        None
# mioffe_M4_984              M4_984    mioffe        None  Female  2018-10-27
# mioffe_M5_696              M5_696    mioffe        None  Female  2019-01-21
# mioffe_M6_672              M6_672    mioffe        None  Female        None
# mioffe_M7_669              M7_669    mioffe        None    Male  2019-01-05
# mioffe_M7_669_2          M7_669_2    mioffe        None    Male        None
# mioffe_M8_689              M8_689    mioffe        None  Female  2019-01-22
# mioffe_M9_698              M9_698    mioffe        None  Female        None
# testuser_T01                  T01  testuser        None  Female  2019-01-23
# testuser_T02                  T02  testuser        None    Male  2019-01-25
# testuser_T03                  T03  testuser        None    Male  2019-02-01
# testuser_T05                  T05  testuser        None    Male  2019-01-23
# testuser_T06                  T06  testuser        None    Male  2019-01-13
# testuser_T07                  T07  testuser        None    Male  2019-01-23
# testuser_T08                  T08  testuser        None    Male  2019-01-23
# testuser_T09                  T09  testuser        None    Male  2019-01-23
# testuser_T10                  T10  testuser        None    Male  2019-01-23
# testuser_T12                  T12  testuser        None    Male  2019-02-10
# testuser_T13                  T13  testuser        None    Male        None
# testuser_T14                  T14  testuser        None    Male  2019-01-23
# testuser_T15                  T15  testuser        None    Male        None
# testuser_T17                  T17  testuser        None    Male  2017-05-05
# testuser_T18                  T18  testuser        None    Male  2019-01-23
# testuser_T19                  T19  testuser        None    Male  2017-04-04
# testuser_T20                  T20  testuser        None    Male  2019-01-23
# zhihaoz_zz24                 zz24   zhihaoz        None    Male        None
# zhihaoz_zz25                 zz25   zhihaoz        None    Male        None
# zhihaoz_ZZ41                 ZZ41   zhihaoz        None    Male        None
#
#                                                     head_plate_mark  location  \
# subject_fullname
# emanuele_B205     [[[253, 253, 253], [246, 251, 252], [193, 241,...  vivarium
# emanuele_B208     [[[252, 252, 252], [245, 214, 208], [251, 246,...  vivarium
# emanuele_B3151    [[[253, 253, 253], [254, 253, 253], [255, 253,...  vivarium
# emanuele_B4486    [[[252, 251, 251], [252, 248, 248], [247, 195,...  vivarium
# emanuele_B4487    [[[210, 210, 210], [115, 115, 115], [215, 215,...  vivarium
# emanuele_B4488    [[[253, 253, 253], [215, 172, 247], [166, 70, ...  vivarium
# emanuele_B4489    [[[253, 253, 253], [253, 253, 253], [243, 244,...  vivarium
# hnieh_E18                                                      None  valhalla
# hnieh_E26         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E36                                                      None  vivarium
# hnieh_E38         [[[193, 165, 227], [236, 229, 245], [252, 252,...  vivarium
# hnieh_E39         [[[34, 35, 255], [151, 152, 255], [36, 37, 255...  vivarium
# hnieh_E42         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E43         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E44         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E45         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E47         [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# hnieh_E48         [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# hnieh_E49         [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# hnieh_E50         [[[113, 6, 243], [149, 69, 245], [253, 252, 25...  vivarium
# hnieh_E51         [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# hnieh_E52         [[[252, 252, 252], [252, 252, 252], [252, 252,...  vivarium
# hnieh_E53         [[[252, 252, 252], [252, 252, 252], [252, 252,...  vivarium
# hnieh_E54                                                      None  valhalla
# hnieh_E55         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E56         [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# hnieh_E57         [[[252, 252, 252], [252, 252, 252], [252, 252,...  vivarium
# hnieh_E58                                                      None  vivarium
# hnieh_E59         [[[255, 255, 255], [237, 248, 240], [145, 209,...  vivarium
# hnieh_E61         [[[247, 3, 56], [249, 100, 109], [255, 243, 24...  vivarium
# ...                                                             ...       ...
# mioffe_m21_202    [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M2_960     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M3_981     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M4_984     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M5_696     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M6_672     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M7_669     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M7_669_2                                                None  vivarium
# mioffe_M8_689     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# mioffe_M9_698     [[[253, 253, 253], [253, 253, 253], [253, 253,...  vivarium
# testuser_T01      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T02      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T03      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T05      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T06      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T07      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T08      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T09      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T10      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T12      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T13      [[[255, 255, 255], [255, 255, 255], [255, 255,...  vivarium
# testuser_T14      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T15      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T17      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T18      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T19      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# testuser_T20      [[[255, 255, 255], [255, 255, 255], [255, 255,...  valhalla
# zhihaoz_zz24                                                   None  vivarium
# zhihaoz_zz25                                                   None  vivarium
# zhihaoz_ZZ41                                                   None  vivarium
#
#                  protocol                       line subject_description  \
# subject_fullname
# emanuele_B205        1910               DAT-IRES-CRE
# emanuele_B208        1910               DAT-IRES-CRE
# emanuele_B3151       1910               DAT-IRES-CRE
# emanuele_B4486       1910               DAT-IRES-CRE
# emanuele_B4487       1910               DAT-IRES-CRE
# emanuele_B4488       1910                    Unknown
# emanuele_B4489       1910                    Unknown
# hnieh_E18            1910                    Unknown
# hnieh_E26            1910                    Unknown
# hnieh_E36            1910                    Unknown
# hnieh_E38            1910                    Unknown
# hnieh_E39            1910                    Unknown
# hnieh_E42            1910                    Unknown
# hnieh_E43            1910                    Unknown
# hnieh_E44            1910                    Unknown
# hnieh_E45            1910                    Unknown
# hnieh_E47            1910                    Unknown
# hnieh_E48            1910                    Unknown
# hnieh_E49            1910                    Unknown
# hnieh_E50            1910                    Unknown
# hnieh_E51            1910                    Unknown
# hnieh_E52            1910                    Unknown
# hnieh_E53            1910                    Unknown
# hnieh_E54            1910                  Ai93-Emx1
# hnieh_E55            1910                    Unknown
# hnieh_E56            1910                    Unknown
# hnieh_E57            1910                    Unknown
# hnieh_E58            1910                  Ai93-Emx1
# hnieh_E59            1910                    Unknown
# hnieh_E61            1910                 Thy1-GP5.3
# ...                   ...                        ...                 ...
# mioffe_m21_202       1910                    Unknown
# mioffe_M2_960        1910                   C57BL6/J
# mioffe_M3_981        1910                   C57BL6/J
# mioffe_M4_984        1910                   C57BL6/J
# mioffe_M5_696        1910                    Unknown
# mioffe_M6_672        1910                    Unknown
# mioffe_M7_669        1910  Ai93-Emx1 (Cre+eGFP-TTA+)
# mioffe_M7_669_2      1910                    Unknown
# mioffe_M8_689        1910  Ai93-Emx1 (Cre+eGFP-TTA-)
# mioffe_M9_698        1910                    Unknown
# testuser_T01         1910                 Thy1-GP5.3
# testuser_T02         1910                   C57BL6/J
# testuser_T03         1910                   C57BL6/J
# testuser_T05         1910                   C57BL6/J
# testuser_T06         1910                     D1-CRE
# testuser_T07         1910             VGAT-ChR2-EYFP
# testuser_T08         1910                     D2-CRE
# testuser_T09         1910               DAT-IRES-CRE
# testuser_T10         1910                   C57BL6/J
# testuser_T12         1910                  DAT-Ai148
# testuser_T13         1910                    Unknown
# testuser_T14         1910                    Unknown
# testuser_T15         1910                    Unknown
# testuser_T17         1910                     D1-CRE
# testuser_T18         1910                    Unknown
# testuser_T19         1910                    Unknown
# testuser_T20         1910                    Unknown
# zhihaoz_zz24         1910                    Unknown
# zhihaoz_zz25         1910                    Unknown
# zhihaoz_ZZ41         1910                    Unknown
#
#                   initial_weight
# subject_fullname
# emanuele_B205               27.0
# emanuele_B208               27.0
# emanuele_B3151              27.0
# emanuele_B4486              27.0
# emanuele_B4487              27.0
# emanuele_B4488              27.0
# emanuele_B4489              27.0
# hnieh_E18                   26.0
# hnieh_E26                   24.0
# hnieh_E36                   23.0
# hnieh_E38                   26.0
# hnieh_E39                   26.0
# hnieh_E42                   27.0
# hnieh_E43                   21.0
# hnieh_E44                   21.0
# hnieh_E45                   30.7
# hnieh_E47                   27.0
# hnieh_E48                   27.0
# hnieh_E49                   27.0
# hnieh_E50                   21.0
# hnieh_E51                   21.0
# hnieh_E52                   28.0
# hnieh_E53                   26.0
# hnieh_E54                   27.0
# hnieh_E55                   28.0
# hnieh_E56                   28.0
# hnieh_E57                   29.0
# hnieh_E58                   28.2
# hnieh_E59                   28.0
# hnieh_E61                   22.5
# ...                          ...
# mioffe_m21_202              28.5
# mioffe_M2_960               33.0
# mioffe_M3_981               30.0
# mioffe_M4_984               25.5
# mioffe_M5_696               15.0
# mioffe_M6_672               22.7
# mioffe_M7_669               24.9
# mioffe_M7_669_2             24.8
# mioffe_M8_689               18.7
# mioffe_M9_698               20.5
# testuser_T01                23.5
# testuser_T02                22.0
# testuser_T03                18.0
# testuser_T05                19.0
# testuser_T06                25.0
# testuser_T07                19.0
# testuser_T08                19.0
# testuser_T09                24.0
# testuser_T10                22.0
# testuser_T12                19.0
# testuser_T13                26.0
# testuser_T14                26.0
# testuser_T15                26.0
# testuser_T17                23.0
# testuser_T18                25.0
# testuser_T19                25.0
# testuser_T20                28.0
# zhihaoz_zz24                24.2
# zhihaoz_zz25                23.7
# zhihaoz_ZZ41                23.6
#
# [191 rows x 11 columns]

# %%
# fetch the primary key
pk = subject.Subject.fetch('KEY')
pk
# Out:
# [{'subject_fullname': 'emanuele_B205'},
#  {'subject_fullname': 'emanuele_B208'},
#  {'subject_fullname': 'emanuele_B3151'},
#  {'subject_fullname': 'emanuele_B4486'},
#  {'subject_fullname': 'emanuele_B4487'},
#  {'subject_fullname': 'emanuele_B4488'},
#  {'subject_fullname': 'emanuele_B4489'},
#  {'subject_fullname': 'hnieh_E18'},
#  {'subject_fullname': 'hnieh_E26'},
#  {'subject_fullname': 'hnieh_E36'},
#  {'subject_fullname': 'hnieh_E38'},
#  {'subject_fullname': 'hnieh_E39'},
#  {'subject_fullname': 'hnieh_E42'},
#  {'subject_fullname': 'hnieh_E43'},
#  {'subject_fullname': 'hnieh_E44'},
#  {'subject_fullname': 'hnieh_E45'},
#  {'subject_fullname': 'hnieh_E47'},
#  {'subject_fullname': 'hnieh_E48'},
#  {'subject_fullname': 'hnieh_E49'},
#  {'subject_fullname': 'hnieh_E50'},
#  {'subject_fullname': 'hnieh_E51'},
#  {'subject_fullname': 'hnieh_E52'},
#  {'subject_fullname': 'hnieh_E53'},
#  {'subject_fullname': 'hnieh_E54'},
#  {'subject_fullname': 'hnieh_E55'},
#  {'subject_fullname': 'hnieh_E56'},
#  {'subject_fullname': 'hnieh_E57'},
#  {'subject_fullname': 'hnieh_E58'},
#  {'subject_fullname': 'hnieh_E59'},
#  {'subject_fullname': 'hnieh_E61'},
#  {'subject_fullname': 'hnieh_E62'},
#  {'subject_fullname': 'hnieh_E63'},
#  {'subject_fullname': 'hnieh_E64'},
#  {'subject_fullname': 'hnieh_E65'},
#  {'subject_fullname': 'hnieh_E66'},
#  {'subject_fullname': 'hnieh_E67'},
#  {'subject_fullname': 'hnieh_E68'},
#  {'subject_fullname': 'hnieh_E69'},
#  {'subject_fullname': 'hnieh_E70'},
#  {'subject_fullname': 'hnieh_E71'},
#  {'subject_fullname': 'hnieh_E74'},
#  {'subject_fullname': 'hnieh_E75'},
#  {'subject_fullname': 'hnieh_E76'},
#  {'subject_fullname': 'hnieh_E77'},
#  {'subject_fullname': 'hnieh_E78'},
#  {'subject_fullname': 'hnieh_E79'},
#  {'subject_fullname': 'hnieh_E80'},
#  {'subject_fullname': 'hnieh_E82'},
#  {'subject_fullname': 'hnieh_E83'},
#  {'subject_fullname': 'hnieh_E84'},
#  {'subject_fullname': 'hnieh_E85'},
#  {'subject_fullname': 'hnieh_E86'},
#  {'subject_fullname': 'hnieh_E87'},
#  {'subject_fullname': 'hnieh_E88'},
#  {'subject_fullname': 'hnieh_J131'},
#  {'subject_fullname': 'hnieh_J132'},
#  {'subject_fullname': 'hnieh_J133'},
#  {'subject_fullname': 'koay_E30'},
#  {'subject_fullname': 'koay_E34'},
#  {'subject_fullname': 'koay_E35'},
#  {'subject_fullname': 'koay_K52'},
#  {'subject_fullname': 'koay_K55'},
#  {'subject_fullname': 'koay_K58'},
#  {'subject_fullname': 'koay_K59'},
#  {'subject_fullname': 'koay_K60'},
#  {'subject_fullname': 'koay_K61'},
#  {'subject_fullname': 'koay_K62'},
#  {'subject_fullname': 'koay_K63'},
#  {'subject_fullname': 'koay_K64'},
#  {'subject_fullname': 'koay_K65'},
#  {'subject_fullname': 'koay_K66'},
#  {'subject_fullname': 'koay_K67'},
#  {'subject_fullname': 'koay_K68'},
#  {'subject_fullname': 'koay_kp1'},
#  {'subject_fullname': 'koay_KP2'},
#  {'subject_fullname': 'koay_KP3'},
#  {'subject_fullname': 'lpinto_ai10'},
#  {'subject_fullname': 'lpinto_ai11'},
#  {'subject_fullname': 'lpinto_ai12'},
#  {'subject_fullname': 'lpinto_ai13'},
#  {'subject_fullname': 'lpinto_ai7'},
#  {'subject_fullname': 'lpinto_ai8'},
#  {'subject_fullname': 'lpinto_ai9'},
#  {'subject_fullname': 'lpinto_GP1'},
#  {'subject_fullname': 'lpinto_GP2'},
#  {'subject_fullname': 'lpinto_GP3'},
#  {'subject_fullname': 'lpinto_GP4'},
#  {'subject_fullname': 'lpinto_GP5'},
#  {'subject_fullname': 'lpinto_GP6'},
#  {'subject_fullname': 'lpinto_SL1'},
#  {'subject_fullname': 'lpinto_SL2'},
#  {'subject_fullname': 'lpinto_SL3'},
#  {'subject_fullname': 'lpinto_SL4'},
#  {'subject_fullname': 'lpinto_SL5'},
#  {'subject_fullname': 'lpinto_SL6'},
#  {'subject_fullname': 'lpinto_SL7'},
#  {'subject_fullname': 'lpinto_SP1'},
#  {'subject_fullname': 'lpinto_SP10'},
#  {'subject_fullname': 'lpinto_SP11'},
#  {'subject_fullname': 'lpinto_SP12'},
#  {'subject_fullname': 'lpinto_SP13'},
#  {'subject_fullname': 'lpinto_SP14'},
#  {'subject_fullname': 'lpinto_SP2'},
#  {'subject_fullname': 'lpinto_SP3'},
#  {'subject_fullname': 'lpinto_SP4'},
#  {'subject_fullname': 'lpinto_SP5'},
#  {'subject_fullname': 'lpinto_SP6'},
#  {'subject_fullname': 'lpinto_SP7'},
#  {'subject_fullname': 'lpinto_SP8'},
#  {'subject_fullname': 'lpinto_SP9'},
#  {'subject_fullname': 'lpinto_vg1'},
#  {'subject_fullname': 'lpinto_vg12'},
#  {'subject_fullname': 'lpinto_vg15'},
#  {'subject_fullname': 'lpinto_vg16'},
#  {'subject_fullname': 'lpinto_vg17'},
#  {'subject_fullname': 'lpinto_vg18'},
#  {'subject_fullname': 'lpinto_vg20'},
#  {'subject_fullname': 'lpinto_vg21'},
#  {'subject_fullname': 'lpinto_vg22'},
#  {'subject_fullname': 'lpinto_vg23'},
#  {'subject_fullname': 'lpinto_vg24'},
#  {'subject_fullname': 'lpinto_vg25'},
#  {'subject_fullname': 'lpinto_vg26'},
#  {'subject_fullname': 'lpinto_vg27'},
#  {'subject_fullname': 'lpinto_vg28'},
#  {'subject_fullname': 'lpinto_vg29'},
#  {'subject_fullname': 'lpinto_vg3'},
#  {'subject_fullname': 'lpinto_vg30'},
#  {'subject_fullname': 'lpinto_vg31'},
#  {'subject_fullname': 'lpinto_vg32'},
#  {'subject_fullname': 'lpinto_vg33'},
#  {'subject_fullname': 'lpinto_vg34'},
#  {'subject_fullname': 'lpinto_vg36'},
#  {'subject_fullname': 'lpinto_vg37'},
#  {'subject_fullname': 'lpinto_vg38'},
#  {'subject_fullname': 'lpinto_VG39'},
#  {'subject_fullname': 'lpinto_VG40'},
#  {'subject_fullname': 'lpinto_VG41'},
#  {'subject_fullname': 'lpinto_VG42'},
#  {'subject_fullname': 'lpinto_VG43'},
#  {'subject_fullname': 'lpinto_VG44'},
#  {'subject_fullname': 'lpinto_VG45'},
#  {'subject_fullname': 'lpinto_VG46'},
#  {'subject_fullname': 'lpinto_VG47'},
#  {'subject_fullname': 'lpinto_VG48'},
#  {'subject_fullname': 'lpinto_VG49'},
#  {'subject_fullname': 'lpinto_VG50'},
#  {'subject_fullname': 'lpinto_VG51'},
#  {'subject_fullname': 'lpinto_VG52'},
#  {'subject_fullname': 'lpinto_VG53'},
#  {'subject_fullname': 'mioffe_M10'},
#  {'subject_fullname': 'mioffe_M10_604'},
#  {'subject_fullname': 'mioffe_M11_605'},
#  {'subject_fullname': 'mioffe_M12_602'},
#  {'subject_fullname': 'mioffe_m13'},
#  {'subject_fullname': 'mioffe_m14'},
#  {'subject_fullname': 'mioffe_m16'},
#  {'subject_fullname': 'mioffe_m17'},
#  {'subject_fullname': 'mioffe_m18'},
#  {'subject_fullname': 'mioffe_m19_203'},
#  {'subject_fullname': 'mioffe_m20_200'},
#  {'subject_fullname': 'mioffe_m21_202'},
#  {'subject_fullname': 'mioffe_M2_960'},
#  {'subject_fullname': 'mioffe_M3_981'},
#  {'subject_fullname': 'mioffe_M4_984'},
#  {'subject_fullname': 'mioffe_M5_696'},
#  {'subject_fullname': 'mioffe_M6_672'},
#  {'subject_fullname': 'mioffe_M7_669'},
#  {'subject_fullname': 'mioffe_M7_669_2'},
#  {'subject_fullname': 'mioffe_M8_689'},
#  {'subject_fullname': 'mioffe_M9_698'},
#  {'subject_fullname': 'testuser_T01'},
#  {'subject_fullname': 'testuser_T02'},
#  {'subject_fullname': 'testuser_T03'},
#  {'subject_fullname': 'testuser_T05'},
#  {'subject_fullname': 'testuser_T06'},
#  {'subject_fullname': 'testuser_T07'},
#  {'subject_fullname': 'testuser_T08'},
#  {'subject_fullname': 'testuser_T09'},
#  {'subject_fullname': 'testuser_T10'},
#  {'subject_fullname': 'testuser_T12'},
#  {'subject_fullname': 'testuser_T13'},
#  {'subject_fullname': 'testuser_T14'},
#  {'subject_fullname': 'testuser_T15'},
#  {'subject_fullname': 'testuser_T17'},
#  {'subject_fullname': 'testuser_T18'},
#  {'subject_fullname': 'testuser_T19'},
#  {'subject_fullname': 'testuser_T20'},
#  {'subject_fullname': 'zhihaoz_zz24'},
#  {'subject_fullname': 'zhihaoz_zz25'},
#  {'subject_fullname': 'zhihaoz_ZZ41'}]

# %%
# fetch specific attributes
dob, sex = subject.Subject.fetch('dob', 'sex')

# %%
dob
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, datetime.date(2016, 11, 14), None,
#        datetime.date(2017, 7, 27), datetime.date(2017, 7, 27),
#        datetime.date(2017, 4, 2), datetime.date(2017, 7, 27),
#        datetime.date(2017, 7, 27), datetime.date(2017, 6, 15),
#        datetime.date(2017, 11, 20), datetime.date(2018, 1, 18),
#        datetime.date(2018, 1, 18), datetime.date(2017, 11, 20),
#        datetime.date(2017, 11, 20), datetime.date(2017, 12, 13),
#        datetime.date(2017, 12, 13), datetime.date(2018, 3, 25),
#        datetime.date(2017, 11, 8), datetime.date(2017, 11, 8),
#        datetime.date(2017, 5, 3), None, datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 24), datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 8), None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None,
#        datetime.date(2017, 11, 8), datetime.date(2017, 11, 8),
#        datetime.date(2017, 11, 6), datetime.date(2017, 11, 8),
#        datetime.date(2017, 1, 3), datetime.date(2017, 1, 3),
#        datetime.date(2017, 11, 8), datetime.date(2018, 10, 24),
#        datetime.date(2018, 10, 24), datetime.date(2018, 10, 22),
#        datetime.date(2018, 10, 22), datetime.date(2018, 10, 28),
#        datetime.date(2018, 10, 28), datetime.date(2017, 10, 26), None,
#        None, None, None, datetime.date(2017, 12, 23),
#        datetime.date(2017, 12, 23), datetime.date(2019, 3, 27),
#        datetime.date(2019, 9, 2), datetime.date(2019, 9, 2),
#        datetime.date(2019, 8, 17), datetime.date(2019, 8, 17),
#        datetime.date(2019, 8, 17), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 3, 27), datetime.date(2019, 3, 27),
#        datetime.date(2019, 8, 29), None, None, None, None, None, None,
#        None, None, None, None, datetime.date(2017, 8, 9),
#        datetime.date(2017, 8, 9), datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), None, datetime.date(2017, 8, 26),
#        datetime.date(2017, 8, 26), None, None, None,
#        datetime.date(2018, 4, 20), datetime.date(2018, 4, 20),
#        datetime.date(2018, 4, 20), datetime.date(2018, 11, 23),
#        datetime.date(2018, 11, 23), datetime.date(2018, 11, 23),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2018, 10, 11), datetime.date(2018, 10, 11),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 21), None,
#        datetime.date(2019, 2, 10), None, None, None, None, None, None,
#        None, None, None, None, datetime.date(2018, 10, 11), None,
#        datetime.date(2018, 10, 27), datetime.date(2019, 1, 21), None,
#        datetime.date(2019, 1, 5), None, datetime.date(2019, 1, 22), None,
#        datetime.date(2019, 1, 23), datetime.date(2019, 1, 25),
#        datetime.date(2019, 2, 1), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 13), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 23), datetime.date(2019, 1, 23),
#        datetime.date(2019, 1, 23), datetime.date(2019, 2, 10), None,
#        datetime.date(2019, 1, 23), None, datetime.date(2017, 5, 5),
#        datetime.date(2019, 1, 23), datetime.date(2017, 4, 4),
#        datetime.date(2019, 1, 23), None, None, None], dtype=object)

# %%
# fetch specific attributes as a list of dictionary
info = subject.Subject.fetch('dob', 'sex', as_dict=True)
info
# Out:
# [{'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2016, 11, 14)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2017, 7, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 7, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 4, 2)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 7, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 7, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 6, 15)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 11, 20)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 1, 18)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 1, 18)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 11, 20)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 11, 20)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 12, 13)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 12, 13)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 3, 25)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 5, 3)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 24)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 24)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 24)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 8)},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 11, 6)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 1, 3)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 1, 3)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 11, 8)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 24)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 24)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 22)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 22)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 28)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 28)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 10, 26)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2017, 12, 23)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 12, 23)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 9, 2)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 9, 2)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 8, 17)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 8, 17)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 8, 17)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 3, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 8, 29)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2017, 8, 9)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 8, 9)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Female', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 8, 26)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2018, 4, 20)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 4, 20)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 4, 20)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 11, 23)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 11, 23)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 11, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 4, 21)},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2019, 2, 10)},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2018, 10, 11)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2018, 10, 27)},
#  {'sex': 'Female', 'dob': datetime.date(2019, 1, 21)},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 5)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2019, 1, 22)},
#  {'sex': 'Female', 'dob': None},
#  {'sex': 'Female', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 25)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 2, 1)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 13)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 2, 10)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': datetime.date(2017, 5, 5)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': datetime.date(2017, 4, 4)},
#  {'sex': 'Male', 'dob': datetime.date(2019, 1, 23)},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None},
#  {'sex': 'Male', 'dob': None}]

# %% [markdown]
# ## fetch data only from one entry: `fetch1`

# %%
B205 = (subject.Subject & {'subject_nickname': 'B205'}).fetch1()  # "fetch1()" because we know there's only one

# %%
B205
# Out:
# {'subject_fullname': 'emanuele_B205',
#  'subject_nickname': 'B205',
#  'user_id': 'emanuele',
#  'genomics_id': None,
#  'sex': 'Male',
#  'dob': None,
#  'head_plate_mark': array([[[253, 253, 253],
#          [246, 251, 252],
#          [193, 241, 251],
#          ...,
#          [ 64, 215, 246],
#          [105, 224, 248],
#          [251, 251, 251]],
#
#         [[255, 255, 255],
#          [239, 252, 254],
#          [ 60, 217, 249],
#          ...,
#          [ 34, 212, 248],
#          [ 58, 217, 249],
#          [254, 253, 253]],
#
#         [[254, 255, 255],
#          [172, 239, 252],
#          [ 55, 216, 249],
#          ...,
#          [ 64, 218, 249],
#          [ 37, 212, 248],
#          [142, 231, 249]],
#
#         ...,
#
#         [[175, 239, 252],
#          [  0, 202, 247],
#          [ 40, 213, 248],
#          ...,
#          [ 13, 207, 247],
#          [ 78, 221, 250],
#          [255, 254, 253]],
#
#         [[197, 244, 253],
#          [  0, 202, 247],
#          [ 78, 220, 249],
#          ...,
#          [  3, 205, 247],
#          [ 86, 222, 250],
#          [255, 254, 253]],
#
#         [[232, 250, 254],
#          [ 30, 210, 248],
#          [149, 234, 252],
#          ...,
#          [ 20, 208, 248],
#          [157, 236, 252],
#          [255, 255, 253]]], dtype=uint8),
#  'location': 'vivarium',
#  'protocol': '1910',
#  'line': 'DAT-IRES-CRE',
#  'subject_description': '',
#  'initial_weight': 27.0}

# %%
B205_key = (subject.Subject & {'subject_nickname': 'B205'}).fetch1('KEY')

# %%
B205_key
# Out:
# {'subject_fullname': 'emanuele_B205'}

# %%
B205_init_weight = (subject.Subject & {'subject_nickname': 'B205'}).fetch1('initial_weight')

# %%
B205_init_weight
# Out:
# 27.0
