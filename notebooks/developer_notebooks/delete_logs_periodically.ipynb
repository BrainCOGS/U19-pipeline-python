# %% [markdown]
# # Check sync process

# %%
from scripts.conf_file_finding import try_find_conf_file
try_find_conf_file()
# Out:
# Local configuration file found !!, no need to run the configuration (unless configuration has changed)

# %%
import pandas as pd
import pathlib
import re
import datetime

# %%
def extract_filename(x):
    return x.name

# %%
#Behavior data
directory_path = pathlib.Path('Z:\Shared\log')
date_pattern = r"_\d{8}_"
reference_date = datetime.date.today() - datetime.timedelta(days=1)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\luna_\AppData\Local\Temp\ipykernel_28052\1747622081.py:2: SyntaxWarning: invalid escape sequence '\S'
#   directory_path = pathlib.Path('Z:\Shared\log')

# %%
files = [p for p in directory_path.rglob("*") if p.is_file() and re.search(date_pattern, p.name)]

# %%
files = [p for p in directory_path.rglob("*") if p.is_file() and re.search(date_pattern, p.name)]


files_df = pd.DataFrame(files, columns=['filepaths'])
files_df['filename'] = files_df['filepaths'].apply(extract_filename)
files_df['exctract_date'] = files_df['filename'].str.extract(r'(\d{8,' + str(8) + r'})')
files_df['exctract_date'] = pd.to_datetime(files_df['exctract_date'], format='%Y%m%d')
files_df['before_ref_date'] = files_df['exctract_date'] <= pd.Timestamp(reference_date)



files_for_deletion = files_df.loc[files_df['before_ref_date']==True, 'filepaths'].to_list()

# %%
files_df
# Out:
#                                              filepaths  \
# 0    Z:\Shared\log\night_cronjob_log\night_cron_log...
# 1    Z:\Shared\log\live_stats_monitor\lsmlog2_20251...
# 2    Z:\Shared\log\live_stats_monitor\lsmlog2_20251...
# 3    Z:\Shared\log\live_stats_monitor\lsmlog2_20251...
# 4    Z:\Shared\log\live_stats_monitor\lsmlog2_20251...
# ..                                                 ...
# 177  Z:\Shared\log\automation_pipeline_log\aplog_20...
# 178  Z:\Shared\log\automation_pipeline_log\aplog_20...
# 179  Z:\Shared\log\automation_pipeline_log\aplog_20...
# 180  Z:\Shared\log\automation_pipeline_log\aplog_20...
# 181  Z:\Shared\log\automation_pipeline_log\aplog_20...
#
#                           filename exctract_date  before_ref_date
# 0    night_cron_log2_20251118_0400    2025-11-18            False
# 1            lsmlog2_20251118_0655    2025-11-18            False
# 2            lsmlog2_20251118_0450    2025-11-18            False
# 3            lsmlog2_20251118_0330    2025-11-18            False
# 4            lsmlog2_20251118_0220    2025-11-18            False
# ..                             ...           ...              ...
# 177            aplog_20251118_0100    2025-11-18            False
# 178            aplog_20251118_0230    2025-11-18            False
# 179            aplog_20251118_0130    2025-11-18            False
# 180            aplog_20251118_0400    2025-11-18            False
# 181            aplog_20251118_0000    2025-11-18            False
#
# [182 rows x 4 columns]

# %%
for file_path in files_for_deletion:
    if file_path.is_file():  # Check if it's actually a file before attempting to delete
        file_path.unlink()

# %%
reference_date
# Out:
# datetime.date(2025, 11, 17)
