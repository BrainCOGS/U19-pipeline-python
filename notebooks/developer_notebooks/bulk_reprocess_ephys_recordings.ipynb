# %% [markdown]
# # Check sync process

# %%
from scripts.conf_file_finding import try_find_conf_file
try_find_conf_file()
# Out:
# Local configuration file found !!, no need to run the configuration (unless configuration has changed)

# %%
import pandas as pd
import numpy as np
import datajoint as dj
# Out:
# c:\Users\MiniVR-8\miniconda3\envs\u19_pipeline_python_env\Lib\site-packages\datajoint\plugin.py:4: UserWarning: Module scripts was already imported from None, but c:\experiments\u19-pipeline-python is being added to sys.path
#   import pkg_resources

# %%
#Behavior data
recording_process = dj.create_virtual_module('recording_process', 'u19_recording_process')
recording = dj.create_virtual_module('recording', 'u19_recording')
#EphysPipeline = dj.create_virtual_module('ephys_pipeline', 'u19_ephys_pipeline')

# %%
subject_fullname like ('')


recording_process.Processing * recording.Recording * recording.Recording.BehaviorSession &)  .fetch()
# Out:
#   Cell In[7], line 4
#     recording_process.Processing * recording.Recording * recording.Recording.BehaviorSession &)  .fetch()
#                                                                                               ^
# SyntaxError: unmatched ')'

# %%
SELECT * FROM tablename
SELECT * FROM tablename

WHERE column LIKE 'M510%'

OR    column LIKE 'M615%'

OR    column LIKE 'M515%'

OR    column LIKE 'M612%';SELECT * FROM tablename

WHERE column LIKE 'M510%'

OR    column LIKE 'M615%'

OR    column LIKE 'M515%'

OR    column LIKE 'M612%';
WHERE column LIKE 'M510%'

OR    column LIKE 'M615%'

OR    column LIKE 'M515%'

OR    column LIKE 'M612%';
