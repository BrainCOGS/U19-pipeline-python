# %% [markdown]
# # Notebook to generate psychometrics plot given sessions & conditions

# %%
import datajoint as dj
import numpy as np
import pylab as plt
import pandas as pd
import json
import datetime
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ### Datajoint configuration

# %% [markdown]
# ### Connection to DB

# %%
conn = dj.conn()
action = dj.create_virtual_module('action', 'u19_test_action')
subject = dj.create_virtual_module('subject', 'u19_test_subject')
lab = dj.create_virtual_module('lab', 'u19_test_lab')
# Out:
# [2025-06-21 12:29:56,103][INFO]: Connecting alvaros@datajoint00.pni.princeton.edu:3306
# [2025-06-21 12:29:57,761][INFO]: Connected alvaros@datajoint00.pni.princeton.edu:3306

# %%
def index_act(act_list):
    occurrence_dict = {}
    for index, item in enumerate(act_list):
        occurrence_dict.setdefault(item, []).append(index)
    return occurrence_dict

# %%
all_subject_status = pd.DataFrame((action.SubjectStatus * subject.Subject.proj('user_id') * lab.User.proj('tech_responsibility')).fetch(as_dict=True))
all_subject_status = all_subject_status.sort_values(by='effective_date', ascending=False)
all_subject_status = all_subject_status.drop_duplicates(subset='subject_fullname', keep='first')

all_subject_status = all_subject_status.sort_values(by='effective_date', ascending=False)

all_subject_status = all_subject_status.reset_index(drop=True)

all_subject_status['schedule_list'] = all_subject_status['schedule'].apply(lambda x: x.split('/'))
all_subject_status['schedule_set'] = all_subject_status['schedule_list'].apply(lambda x: set(x))
all_subject_status['num_act'] = all_subject_status['schedule_set'].apply(lambda x: len(x))
all_subject_status['index_act'] = all_subject_status['schedule_list'].apply(lambda x: index_act(x))

# %% [markdown]
# ## Activities when one person does everything

# %%
subject_status_dict_owner = {
    'Dead': ['Nothing'],
    'AdLibWater': ['Nothing'],
    'Missing': ['Nothing'],
    'WaterRestrictionOnly': ['Watering', 'Weighing'],
    'InExperiments': ['Watering', 'Weighing', 'Training']
}
subject_status_dict_technician = {
    'Dead': ['Nothing'],
    'AdLibWater': ['Nothing'],
    'Missing': ['Nothing'],
    'WaterRestrictionOnly': ['Watering', 'Weighing', 'Transport'],
    'InExperiments': ['Watering', 'Weighing', 'Training', 'Transport']
}

act_to_status_dict = {
    'Water': 'WaterRestrictionOnly',
    'Weigh': 'WaterRestrictionOnly',
    'Train': 'InExperiments',
    'OnlyTrain': 'InExperiments',
    'Nothing': 'Dead',
    'Transport': 'Dead'

}

# %% [markdown]
# ## Activities when activities are shared (assuming weekends techs do everything)

# %%
subject_status_dict_owner_shared = {
    'Dead': ['Nothing'],
    'AdLibWater': ['Nothing'],
    'Missing': ['Nothing'],
    'WaterRestrictionOnly': ['Watering', 'Weighing'],
    'InExperiments': ['Watering', 'Weighing', 'Training']
}
subject_status_dict_technician_shared = {
    'Dead': ['Nothing'],
    'AdLibWater': ['Nothing'],
    'Missing': ['Nothing'],
    'WaterRestrictionOnly': ['Watering', 'Weighing', 'Transport'],
    'InExperiments': ['Watering', 'Weighing', 'Training', 'Transport']
}

act_to_status_dict_shared = {
    'Water': 'WaterRestrictionOnly',
    'Weigh': 'WaterRestrictionOnly',
    'Train': 'InExperiments',
    'OnlyTrain': 'InExperiments',
    'Nothing': 'Dead',
    'Transport': ['Transport']

}

# %%
base_weekly_dict = {
  "assignment_style": "Specify for the whole week",
  "weekly": ['Nothing']
}

base_weekdays_weekends_dict = {
  "assignment_style": "Specify by weekday/weekend",
  "weekdays": ['Nothing'],
  "weekends": ['Nothing']
}


base_days_dict = {
"assignment_style":"Specify each day",
"Monday": ['Nothing'],
"Tuesday": ['Nothing'],
"Wednesday": ['Nothing'],
"Thursday": ['Nothing'],
"Friday": ['Nothing'],
"Saturday": ['Nothing'],
"Sunday": ['Nothing'],
}

# %%
def translate_schedule(df_row):

    user_id = df_row['user_id']
    schedule_list = df_row['schedule_list']
    tech_responsibility = df_row['tech_responsibility']
    subject_status = df_row['subject_status']
    num_act = df_row['num_act']
    index_act = df_row['index_act']


    tech_act_dict = base_weekly_dict.copy()
    tech_act_dict['weekly'] = ['Nothing']
    owner_act_dict = base_weekly_dict.copy()
    owner_act_dict['weekly'] = ['Nothing']

    if tech_responsibility == 'yes':
        if subject_status in ('Dead', 'AdLibWater', 'Missing'):
            tech_act_dict = base_weekly_dict.copy()
            tech_act_dict['weekly'] = subject_status_dict_technician[subject_status]
        elif num_act == 1:
            tech_act_dict = base_weekly_dict.copy()
            tech_act_dict['weekly'] = subject_status_dict_technician[subject_status]
        elif num_act == 2 and list(index_act.values())[0] == [1,2,3,4,5] or list(index_act.values())[0] == [0,6]:

            tech_act_dict = base_weekdays_weekends_dict.copy()
            weekdays_act = schedule_list[1]
            weekdends_act = schedule_list[6]
            if weekdays_act == 'Transport' or weekdends_act == 'Transport':
                owner_act_dict = base_weekdays_weekends_dict
            if weekdays_act == 'Transport':
                tech_act_dict['weekdays'] = ['Transport']
                owner_act_dict['weekdays'] = subject_status_dict_owner[subject_status]
            else:
                weekdays_status = act_to_status_dict[weekdays_act]
                tech_act_dict['weekdays'] = subject_status_dict_technician[weekdays_status]
            if weekdends_act == 'Transport':
                tech_act_dict['weekends'] = ['Transport']
                owner_act_dict['weekends'] = subject_status_dict_owner[subject_status]
            else:
                weekdends_status = act_to_status_dict[weekdends_act]
                tech_act_dict['weekends'] = subject_status_dict_technician[weekdends_status]
        else:
            tech_act_dict = base_days_dict.copy()

            

            tech_act_dict['Monday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[0]]]
            tech_act_dict['Tuesday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[1]]]
            tech_act_dict['Wednesday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[2]]]
            tech_act_dict['Thursday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[3]]]
            tech_act_dict['Friday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[4]]]
            tech_act_dict['Saturday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[5]]]
            tech_act_dict['Sunday'] = subject_status_dict_technician[act_to_status_dict[schedule_list[6]]]
    
    # Tech_responsibility = no
    else:
        if subject_status not in ('Dead', 'AdLibWater', 'Missing'):
            tech_act_dict['weekly'] = ['Transport']
            if num_act == 1:
                owner_act_dict['weekly'] = subject_status_dict_owner[subject_status]
            elif num_act == 2 and list(index_act.values())[0] == [1,2,3,4,5] or list(index_act.values())[0] == [0,6]:
                owner_act_dict = base_weekdays_weekends_dict.copy()
                weekdays_act = schedule_list[1]
                weekdends_act = schedule_list[6]
                owner_act_dict['weekdays'] = subject_status_dict_owner[subject_status]
                owner_act_dict['weekends'] = subject_status_dict_owner[subject_status]
            else:
                owner_act_dict = base_days_dict.copy()
                schedule_list = [act_to_status_dict[x] if x!='Transport' else x for x in schedule_list]
                schedule_list = [subject_status if x=='Transport' else x for x in schedule_list]

                owner_act_dict['Monday'] = subject_status_dict_owner[schedule_list[0]]
                owner_act_dict['Tuesday'] = subject_status_dict_owner[schedule_list[1]]
                owner_act_dict['Wednesday'] = subject_status_dict_owner[schedule_list[2]]
                owner_act_dict['Thursday'] = subject_status_dict_owner[schedule_list[3]]
                owner_act_dict['Friday'] = subject_status_dict_owner[schedule_list[4]]
                owner_act_dict['Saturday'] = subject_status_dict_owner[schedule_list[5]]
                owner_act_dict['Sunday'] = subject_status_dict_owner[schedule_list[6]]
    
                
    return pd.Series({'technician_duties': json.dumps(tech_act_dict), 'owner_duties': json.dumps(owner_act_dict)})

# %%
all_subject_status[['technician_duties', 'owner_duties']] = all_subject_status.apply(translate_schedule, axis=1)

# %%
all_subject_status
# Out:
#               subject_fullname effective_date   user_id        subject_status  \
# 0                 testuser_T36     2025-06-16  testuser                  Dead
# 1         testuser_monday_tria     2025-06-10  testuser  WaterRestrictionOnly
# 2     testuser_captian_america     2025-06-10  testuser         InExperiments
# 3                  jk8386_jk67     2025-06-09    jk8386            AdLibWater
# 4                  jk8386_jk66     2025-06-09    jk8386         InExperiments
# ...                        ...            ...       ...                   ...
# 1166                 hnieh_E36     2017-09-10     hnieh                  Dead
# 1167                 hnieh_E18     2017-08-16     hnieh                  Dead
# 1168                  koay_K55     2017-08-12      koay                  Dead
# 1169                lpinto_vg1     2017-08-02    lpinto                  Dead
# 1170                lpinto_vg3     2017-08-02    lpinto                  Dead
#
#       water_per_day                                           schedule  \
# 0               1.0          Train/Train/Train/Train/Train/Train/Train
# 1               1.0          Train/Train/Train/Train/Train/Train/Train
# 2               1.0          Train/Train/Train/Train/Train/Train/Train
# 3               1.0          Train/Train/Train/Train/Train/Train/Train
# 4               1.0          Train/Train/Train/Train/Train/Train/Train
# ...             ...                                                ...
# 1166            1.5  Water/Nothing/OnlyTrain/OnlyTrain/OnlyTrain/On...
# 1167            1.5  Water/Nothing/OnlyTrain/OnlyTrain/OnlyTrain/On...
# 1168            1.0          Train/Train/Train/Train/Train/Train/Train
# 1169            1.0          Train/Train/Train/Train/Train/Train/Train
# 1170            1.0          Train/Train/Train/Train/Train/Train/Train
#
#      tech_responsibility                                      schedule_list  \
# 0                     no  [Train, Train, Train, Train, Train, Train, Train]
# 1                     no  [Train, Train, Train, Train, Train, Train, Train]
# 2                     no  [Train, Train, Train, Train, Train, Train, Train]
# 3                    yes  [Train, Train, Train, Train, Train, Train, Train]
# 4                    yes  [Train, Train, Train, Train, Train, Train, Train]
# ...                  ...                                                ...
# 1166                 yes  [Water, Nothing, OnlyTrain, OnlyTrain, OnlyTra...
# 1167                 yes  [Water, Nothing, OnlyTrain, OnlyTrain, OnlyTra...
# 1168                 yes  [Train, Train, Train, Train, Train, Train, Train]
# 1169                 yes  [Train, Train, Train, Train, Train, Train, Train]
# 1170                 yes  [Train, Train, Train, Train, Train, Train, Train]
#
#                             schedule_set  num_act  \
# 0                                {Train}        1
# 1                                {Train}        1
# 2                                {Train}        1
# 3                                {Train}        1
# 4                                {Train}        1
# ...                                  ...      ...
# 1166  {OnlyTrain, Water, Train, Nothing}        4
# 1167  {OnlyTrain, Water, Train, Nothing}        4
# 1168                             {Train}        1
# 1169                             {Train}        1
# 1170                             {Train}        1
#
#                                               index_act  \
# 0                      {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 1                      {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 2                      {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 3                      {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 4                      {'Train': [0, 1, 2, 3, 4, 5, 6]}
# ...                                                 ...
# 1166  {'Water': [0], 'Nothing': [1], 'OnlyTrain': [2...
# 1167  {'Water': [0], 'Nothing': [1], 'OnlyTrain': [2...
# 1168                   {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 1169                   {'Train': [0, 1, 2, 3, 4, 5, 6]}
# 1170                   {'Train': [0, 1, 2, 3, 4, 5, 6]}
#
#                                       technician_duties  \
# 0     {"assignment_style": "Specify for the whole we...
# 1     {"assignment_style": "Specify for the whole we...
# 2     {"assignment_style": "Specify for the whole we...
# 3     {"assignment_style": "Specify for the whole we...
# 4     {"assignment_style": "Specify for the whole we...
# ...                                                 ...
# 1166  {"assignment_style": "Specify for the whole we...
# 1167  {"assignment_style": "Specify for the whole we...
# 1168  {"assignment_style": "Specify for the whole we...
# 1169  {"assignment_style": "Specify for the whole we...
# 1170  {"assignment_style": "Specify for the whole we...
#
#                                            owner_duties
# 0     {"assignment_style": "Specify for the whole we...
# 1     {"assignment_style": "Specify for the whole we...
# 2     {"assignment_style": "Specify for the whole we...
# 3     {"assignment_style": "Specify for the whole we...
# 4     {"assignment_style": "Specify for the whole we...
# ...                                                 ...
# 1166  {"assignment_style": "Specify for the whole we...
# 1167  {"assignment_style": "Specify for the whole we...
# 1168  {"assignment_style": "Specify for the whole we...
# 1169  {"assignment_style": "Specify for the whole we...
# 1170  {"assignment_style": "Specify for the whole we...
#
# [1171 rows x 13 columns]

# %%
all_subject_status['technician_duties'].unique()
# Out:
# array(['{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#        '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#        '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#        '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#        '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}'],
#       dtype=object)

# %%
all_subject_status['owner_duties'].unique()
# Out:
# array(['{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#        '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing"]}',
#        '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}',
#        '{"assignment_style": "Specify each day", "Monday": ["Nothing"], "Tuesday": ["Nothing"], "Wednesday": ["Nothing"], "Thursday": ["Watering", "Weighing", "Training"], "Friday": ["Watering", "Weighing", "Training"], "Saturday": ["Watering", "Weighing", "Training"], "Sunday": ["Watering", "Weighing", "Training"]}',
#        '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}',
#        '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing"], "weekends": ["Nothing"]}',
#        '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}',
#        '{"assignment_style": "Specify each day", "Monday": ["Watering", "Weighing"], "Tuesday": ["Watering", "Weighing"], "Wednesday": ["Nothing"], "Thursday": ["Watering", "Weighing"], "Friday": ["Nothing"], "Saturday": ["Nothing"], "Sunday": ["Nothing"]}',
#        '{"assignment_style": "Specify each day", "Monday": ["Watering", "Weighing"], "Tuesday": ["Watering", "Weighing"], "Wednesday": ["Watering", "Weighing"], "Thursday": ["Watering", "Weighing"], "Friday": ["Watering", "Weighing"], "Saturday": ["Watering", "Weighing"], "Sunday": ["Watering", "Weighing"]}',
#        '{"assignment_style": "Specify each day", "Monday": ["Watering", "Weighing", "Training"], "Tuesday": ["Watering", "Weighing", "Training"], "Wednesday": ["Watering", "Weighing"], "Thursday": ["Watering", "Weighing", "Training"], "Friday": ["Watering", "Weighing", "Training"], "Saturday": ["Watering", "Weighing", "Training"], "Sunday": ["Watering", "Weighing", "Training"]}'],
#       dtype=object)

# %%
all_subject_status.loc[all_subject_status['owner_duties'].str.contains('{"assignment_style": "Specify each day",'),:]
# Out:
#           subject_fullname effective_date   user_id        subject_status  \
# 10         testuser_asdfsd     2025-05-27  testuser         InExperiments
# 98    testuser_meow_meow_2     2025-04-15  testuser  WaterRestrictionOnly
# 533   testuser_christian_1     2024-02-23  testuser  WaterRestrictionOnly
# 1091          testuser_T21     2020-03-23  testuser  WaterRestrictionOnly
#
#       water_per_day                                           schedule  \
# 10              1.0    Nothing/Nothing/Nothing/Train/Train/Train/Train
# 98              1.0  Transport/Weigh/Nothing/Transport/Nothing/Noth...
# 533             1.0          Water/Water/Weigh/Water/Weigh/Water/Weigh
# 1091           10.0      Train/Train/Transport/Train/Train/Train/Train
#
#      tech_responsibility                                      schedule_list  \
# 10                    no  [Nothing, Nothing, Nothing, Train, Train, Trai...
# 98                    no  [Transport, Weigh, Nothing, Transport, Nothing...
# 533                   no  [Water, Water, Weigh, Water, Weigh, Water, Weigh]
# 1091                  no  [Train, Train, Transport, Train, Train, Train,...
#
#                      schedule_set  num_act  \
# 10               {Train, Nothing}        2
# 98    {Transport, Weigh, Nothing}        3
# 533                {Weigh, Water}        2
# 1091           {Transport, Train}        2
#
#                                               index_act  \
# 10        {'Nothing': [0, 1, 2], 'Train': [3, 4, 5, 6]}
# 98    {'Transport': [0, 3], 'Weigh': [1], 'Nothing':...
# 533         {'Water': [0, 1, 3, 5], 'Weigh': [2, 4, 6]}
# 1091    {'Train': [0, 1, 3, 4, 5, 6], 'Transport': [2]}
#
#                                       technician_duties  \
# 10    {"assignment_style": "Specify for the whole we...
# 98    {"assignment_style": "Specify for the whole we...
# 533   {"assignment_style": "Specify for the whole we...
# 1091  {"assignment_style": "Specify for the whole we...
#
#                                            owner_duties
# 10    {"assignment_style": "Specify each day", "Mond...
# 98    {"assignment_style": "Specify each day", "Mond...
# 533   {"assignment_style": "Specify each day", "Mond...
# 1091  {"assignment_style": "Specify each day", "Mond...

# %%
all_subject_status_final = all_subject_status.loc[:, ['subject_fullname', 'subject_status', 'water_per_day', 'technician_duties', 'owner_duties']]
all_subject_status_final
# Out:
#               subject_fullname        subject_status  water_per_day  \
# 0                 testuser_T36                  Dead            1.0
# 1         testuser_monday_tria  WaterRestrictionOnly            1.0
# 2     testuser_captian_america         InExperiments            1.0
# 3                  jk8386_jk67            AdLibWater            1.0
# 4                  jk8386_jk66         InExperiments            1.0
# ...                        ...                   ...            ...
# 1166                 hnieh_E36                  Dead            1.5
# 1167                 hnieh_E18                  Dead            1.5
# 1168                  koay_K55                  Dead            1.0
# 1169                lpinto_vg1                  Dead            1.0
# 1170                lpinto_vg3                  Dead            1.0
#
#                                       technician_duties  \
# 0     {"assignment_style": "Specify for the whole we...
# 1     {"assignment_style": "Specify for the whole we...
# 2     {"assignment_style": "Specify for the whole we...
# 3     {"assignment_style": "Specify for the whole we...
# 4     {"assignment_style": "Specify for the whole we...
# ...                                                 ...
# 1166  {"assignment_style": "Specify for the whole we...
# 1167  {"assignment_style": "Specify for the whole we...
# 1168  {"assignment_style": "Specify for the whole we...
# 1169  {"assignment_style": "Specify for the whole we...
# 1170  {"assignment_style": "Specify for the whole we...
#
#                                            owner_duties
# 0     {"assignment_style": "Specify for the whole we...
# 1     {"assignment_style": "Specify for the whole we...
# 2     {"assignment_style": "Specify for the whole we...
# 3     {"assignment_style": "Specify for the whole we...
# 4     {"assignment_style": "Specify for the whole we...
# ...                                                 ...
# 1166  {"assignment_style": "Specify for the whole we...
# 1167  {"assignment_style": "Specify for the whole we...
# 1168  {"assignment_style": "Specify for the whole we...
# 1169  {"assignment_style": "Specify for the whole we...
# 1170  {"assignment_style": "Specify for the whole we...
#
# [1171 rows x 5 columns]

# %%
all_subject_status_final.to_dict('records')
# Out:
# [{'subject_fullname': 'testuser_T36',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_monday_tria',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing"]}'},
#  {'subject_fullname': 'testuser_captian_america',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jk8386_jk67',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk66',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_weighttest',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jk8386_jk65',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk64',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_aaa',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_mariokart1234',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_asdfsd',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify each day", "Monday": ["Nothing"], "Tuesday": ["Nothing"], "Wednesday": ["Nothing"], "Thursday": ["Watering", "Weighing", "Training"], "Friday": ["Watering", "Weighing", "Training"], "Saturday": ["Watering", "Weighing", "Training"], "Sunday": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_mariokart',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'efonseca_ef559_act121',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk78',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk80',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk79',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_32',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_478',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk71',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.4,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_913',
#   'subject_status': 'Dead',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk83',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_33',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_910',
#   'subject_status': 'Dead',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_569',
#   'subject_status': 'Dead',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_477',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_42',
#   'subject_status': 'Dead',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_40',
#   'subject_status': 'Dead',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya043',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya041',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya044',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya046',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya042',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya045',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j070',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j088',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j085',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j089',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j087',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j064',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j090',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'sbolkan_d1_274',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'sbolkan_d1_281',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'sbolkan_d1_279',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'sbolkan_d1_278',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'sbolkan_d1_277',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_ya041_ff',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'sbolkan_a2a_251',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'sbolkan_a2a_254',
#   'subject_status': 'InExperiments',
#   'water_per_day': 0.9,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jyanar_ya023',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya040',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_ya041fa',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_ya041',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing"]}'},
#  {'subject_fullname': 'jyanar_ya024',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya039',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya036',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya027',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya035',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya028',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya029',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya019',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'sbolkan_a2a_268',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jyanar_ya025',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya031',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya026',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya020',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya033',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya034',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jeremyjc_j065',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya038',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'efonseca_ef756_act123',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'efonseca_ef562_act122',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'efonseca_ef757_act124',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk86',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk73',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk75',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk72',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk87',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk69',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk74',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk84',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk85',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk54',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk62',
#   'subject_status': 'Dead',
#   'water_per_day': 1.8,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_429',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk53',
#   'subject_status': 'Dead',
#   'water_per_day': 2.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk48',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk47',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk43',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_JK41',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk70',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk77',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk82',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk76',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jk8386_jk81',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_testuseruser',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_test',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_1234_vmr',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_fdd',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_meow_meow_2',
#   'subject_status': 'WaterRestrictionOnly',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify each day", "Monday": ["Watering", "Weighing"], "Tuesday": ["Watering", "Weighing"], "Wednesday": ["Nothing"], "Thursday": ["Watering", "Weighing"], "Friday": ["Nothing"], "Saturday": ["Nothing"], "Sunday": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_meow_meow_3',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_test_400',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_test_4000',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_meow_meow',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_meow_meow_4',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_msri',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_msri2',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_InitialWeight',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.5,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_1234',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_1234_vmr2',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_testtestsetest',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_test99',
#   'subject_status': 'InExperiments',
#   'water_per_day': 5.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_test88',
#   'subject_status': 'InExperiments',
#   'water_per_day': 5.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_testtest',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_testtestseteste',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jyanar_ya999',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_test_image_path',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'jyanar_ya021',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_asdfasdfasdf',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_482',
#   'subject_status': 'InExperiments',
#   'water_per_day': 0.9,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_481',
#   'subject_status': 'InExperiments',
#   'water_per_day': 0.9,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_479',
#   'subject_status': 'InExperiments',
#   'water_per_day': 0.9,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_480',
#   'subject_status': 'InExperiments',
#   'water_per_day': 0.9,
#   'technician_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Transport"], "weekends": ["Watering", "Weighing", "Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify by weekday/weekend", "weekdays": ["Watering", "Weighing", "Training"], "weekends": ["Nothing"]}'},
#  {'subject_fullname': 'mjs20_199',
#   'subject_status': 'Dead',
#   'water_per_day': 2.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_asdfasdfsfasd',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_sdfsdsaf',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'vr2617_701',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_709',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_706',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_704',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_712',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_710',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_708',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_703',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_711',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_702',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_707',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'vr2617_714',
#   'subject_status': 'Dead',
#   'water_per_day': 1.1,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya037',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya030',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya032',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'testuser_feb_25_2025',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya016',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jyanar_ya017',
#   'subject_status': 'AdLibWater',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_Thy1_991',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_DAT_694',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_CaMKIIa_tetO_780',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_Thy1_992',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_Thy1_984',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_Thy1_989',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'jounhong_DAT781',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
# ...
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_T50',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'testuser_T35',
#   'subject_status': 'InExperiments',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Transport"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Watering", "Weighing", "Training"]}'},
#  {'subject_fullname': 'emdiamanti_sp18',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_sp20',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps11',
#   'subject_status': 'Dead',
#   'water_per_day': 1.0,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps3',
#   'subject_status': 'Dead',
#   'water_per_day': 1.3,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps4',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps5',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps6',
#   'subject_status': 'Dead',
#   'water_per_day': 1.2,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps7',
#   'subject_status': 'Dead',
#   'water_per_day': 1.3,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps2',
#   'subject_status': 'Dead',
#   'water_per_day': 1.3,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emdiamanti_gps1',
#   'subject_status': 'Dead',
#   'water_per_day': 1.3,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'zhihaoz_zz51',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_m13',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'zhihaoz_zz25',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_SP5',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M11_605',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M10',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'zhihaoz_zz24',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M2_960',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'ariordan_528',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'ariordan_529',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M3_981',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M10_604',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_E58',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_SP8',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_J131',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_E38',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'koay_E34',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_J133',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_J132',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_m21_202',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_E88',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_E87',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'koay_E35',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'hnieh_E86',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'koay_K52',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'koay_K59',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_SP7',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M6_672',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_m16',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_m20_200',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B4489',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M7_669',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B205',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B208',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M8_689',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_VG51',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B3151',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B4486',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'emanuele_B4487',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_VG50',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'mioffe_M7_669_2',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_VG52',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  {'subject_fullname': 'lpinto_VG49',
#   'subject_status': 'Dead',
#   'water_per_day': nan,
#   'technician_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}',
#   'owner_duties': '{"assignment_style": "Specify for the whole week", "weekly": ["Nothing"]}'},
#  ...]

# %%
action.Responsibilities.insert(all_subject_status_final.to_dict('records'))

# %%
all_subject_status_final.loc[288,:]
# Out:
# subject_fullname                                     testuser_test1000
# subject_status                                                 Missing
# water_per_day                                                      5.0
# technician_duties    {"assignment_style": "Specify for the whole we...
# owner_duties         {"assignment_style": "Specify for the whole we...
# Name: 288, dtype: object
