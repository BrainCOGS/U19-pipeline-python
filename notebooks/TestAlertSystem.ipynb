# %% [markdown]
# ### Check if configuration has been run already and change directory to repository root:

# %%
from scripts.conf_file_finding import try_find_conf_file
try_find_conf_file()
# Out:
# Local configuration file found !!, no need to run the configuration (unless configuration has changed)

# %%
import datajoint as dj
import pandas as pd
import datetime
import u19_pipeline.alert_system.main_alert_system as mas
# Out:
# Connecting alvaros@datajoint00.pni.princeton.edu:3306

# %% [markdown]
# ### Run recording main pipeline

# %%
mas.main_alert_system()
# Out:
# aqui rig_bias
# bias_df
#              subject_fullname session_date  session_number      bias
# 0     efonseca_ef255_actgp002   2022-07-22               0 -0.022794
# 1     efonseca_ef255_actgp002   2022-07-21               0 -0.238095
# 2     efonseca_ef255_actgp002   2022-07-20               0 -0.023106
# 3     efonseca_ef255_actgp002   2022-07-19               0 -0.100000
# 4     efonseca_ef255_actgp002   2022-07-18               0  0.051948
# ...                       ...          ...             ...       ...
# 2451           sbolkan_d1_231   2022-06-23               0  0.209601
# 2452           sbolkan_d1_231   2022-06-22               0 -0.234224
# 2453             sbolkan_test   2022-07-06               0  0.142857
# 2454             sbolkan_test   2022-06-21               0 -0.159378
# 2455             sbolkan_test   2022-06-20               0 -0.099118
#
# [2456 rows x 4 columns]
# aqui rig_trial
# aqui subject_bias
# aqui subject trial

# %%
from traceback import print_tb
import u19_pipeline.alert_system.custom_alerts as ca
import importlib

import pkgutil
all_alert_submodules = pkgutil.iter_modules(ca.__path__)

for i in all_alert_submodules:
    my_module = importlib.import_module('u19_pipeline.alert_system.custom_alerts.'+i.name)
    print(my_module)
    my_module.main()
# Out:
# <module 'u19_pipeline.alert_system.custom_alerts.subject_trial_and_bias' from '/Users/alvaros/Documents/MATLAB/BrainCogsProjects/Datajoint_proj/U19-pipeline_python/u19_pipeline/alert_system/custom_alerts/subject_trial_and_bias.py'>
# aqui subject_trial_and_bias
# Connecting alvaros@datajoint00.pni.princeton.edu:3306
# session_date >="2022-08-13"and session_date < "2022-08-18" and subject_fullname not like "testuser%"

# %%
key = dict()
key['subject_fullname'] = 'jjulian_jk001'

behavior = dj.create_virtual_module('behavior', 'u19_behavior')

acquisition = dj.create_virtual_module('behavior', 'u19_acquisition')

#data = pd.DataFrame((behavior.TowersBlock.Trial & key).fetch('KEY', 'trial_duration', 'choice', 'trial_type', as_dict=True))
#data2 = pd.DataFrame((acquisition.Session & key).fetch(as_dict=True))

new_acq_session_started = acquisition.SessionStarted.proj(session_start_time1='session_start_time')

data3 = pd.DataFrame((new_acq_session_started * acquisition.Session * acquisition.SessionErrorLog & key).fetch(as_dict=True))


#data4 = pd.DataFrame(( * acquisition.SessionErrorLog & key).fetch(as_dict=True))


data3
# Out:
#   subject_fullname session_date  session_number  error_log_id  \
# 0    jjulian_jk001   2022-08-04               0           582
# 1    jjulian_jk001   2022-08-05               0           583
# 2    jjulian_jk001   2022-08-12               0           584
# 3    jjulian_jk001   2022-08-13               0           585
# 4    jjulian_jk001   2022-08-16               0           586
# 5    jjulian_jk001   2022-08-17               0           587
# 6    jjulian_jk001   2022-08-18               0           588
#
#   session_start_time1  session_start_time    session_end_time  \
# 0 2022-08-04 12:37:00 2022-08-04 11:58:00 2022-08-04 12:58:00
# 1 2022-08-05 12:28:00 2022-08-05 11:54:00 2022-08-05 12:54:00
# 2 2022-08-12 12:27:00 2022-08-12 12:00:00 2022-08-12 13:00:00
# 3 2022-08-13 13:28:00 2022-08-13 13:29:00 2022-08-13 13:50:00
# 4 2022-08-16 12:00:00 2022-08-16 12:00:00 2022-08-16 12:33:00
# 5 2022-08-17 12:24:00 2022-08-17 11:57:00 2022-08-17 12:57:00
# 6 2022-08-18 12:22:00 2022-08-18 11:57:00 2022-08-18 12:57:00
#
#   session_location    task  level  ...    num_trials_try session_narrative  \
# 0      165A-Rig6-T  Towers      4  ...  [[242.0, 392.0]]
# 1      165A-Rig6-T  Towers      4  ...  [[213.0, 396.0]]
# 2      165A-Rig6-T  Towers      4  ...  [[166.0, 407.0]]
# 3      165A-Rig6-T  Towers      4  ...         [[177.0]]
# 4      165A-Rig6-T  Towers      4  ...         [[238.0]]
# 5      165A-Rig6-T  Towers      4  ...  [[204.0, 447.0]]
# 6      165A-Rig6-T  Towers      4  ...  [[188.0, 420.0]]
#
#                                     session_protocol  session_code_version  \
# 0  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 1  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 2  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 3  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 4  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 5  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
# 6  josh_SpatialFreqContext_reversal.m josh_Spatia...          [[1.0, 4.0]]
#
#    is_bad_session session_comments      error_time session_phase  \
# 0               0                  0 days 12:29:11       Runtime
# 1               0                  0 days 12:23:42       Runtime
# 2               0                  0 days 12:23:24       Runtime
# 3               0                  0 days 13:50:54       Runtime
# 4               0                  0 days 12:33:20       Runtime
# 5               0                  0 days 12:22:36       Runtime
# 6               0                  0 days 12:20:49       Runtime
#
#                           error_message  \
# 0         Serial write error:  Unknown.
# 1         Serial write error:  Unknown.
# 2         Serial write error:  Unknown.
# 3         Serial write error:  Unknown.
# 4         Serial write error:  Unknown.
# 5  Timed out while waiting for a reply.
# 6         Serial write error:  Unknown.
#
#                                      error_exception
# 0  [[[['Serial write error:  Unknown.'], [[(array...
# 1  [[[['Serial write error:  Unknown.'], [[(array...
# 2  [[[['Serial write error:  Unknown.'], [[(array...
# 3  [[[['Serial write error:  Unknown.'], [[(array...
# 4  [[[['Serial write error:  Unknown.'], [[(array...
# 5  [[[['Timed out while waiting for a reply.'], [...
# 6  [[[['Serial write error:  Unknown.'], [[(array...
#
# [7 rows x 25 columns]

# %%
data5 = pd.DataFrame((behavior.TowersBlock * acquisition.SessionErrorLog & key).fetch(as_dict=True))
data5
# Out:
#   subject_fullname session_date  session_number  block  error_log_id    task  \
# 0    jjulian_jk001   2022-08-04               0      1           582  Towers
# 1    jjulian_jk001   2022-08-04               0      2           582  Towers
# 2    jjulian_jk001   2022-08-05               0      1           583  Towers
# 3    jjulian_jk001   2022-08-05               0      2           583  Towers
# 4    jjulian_jk001   2022-08-12               0      1           584  Towers
# 5    jjulian_jk001   2022-08-12               0      2           584  Towers
# 6    jjulian_jk001   2022-08-13               0      1           585  Towers
# 7    jjulian_jk001   2022-08-16               0      1           586  Towers
# 8    jjulian_jk001   2022-08-17               0      1           587  Towers
# 9    jjulian_jk001   2022-08-17               0      2           587  Towers
#
#    main_level  level  set_id  n_trials  ...  block_duration  \
# 0           4      4       1       243  ...         1852.41
# 1           4      4       1       149  ...         1244.56
# 2           4      4       1       214  ...         1739.31
# 3           4      4       1       182  ...         1549.10
# 4           4      4       1       167  ...         1355.15
# 5           4      4       1       240  ...         2014.35
# 6           4      4       1       178  ...         1302.29
# 7           4      4       1       239  ...         1927.91
# 8           4      4       1       205  ...         1509.28
# 9           4      4       1       242  ...         1944.12
#
#      block_start_time reward_mil  reward_scale  easy_block  block_performance  \
# 0 2022-08-04 11:58:00     0.9000             1           0           0.925926
# 1 2022-08-04 12:37:00     1.4080             1           0           0.885906
# 2 2022-08-05 11:54:00     0.7400             1           0           0.864486
# 3 2022-08-05 12:28:00     0.7624             1           0           0.873626
# 4 2022-08-12 12:00:00     0.6080             1           0           0.910180
# 5 2022-08-12 12:27:00     1.1992             1           0           0.937500
# 6 2022-08-13 13:29:00     0.7000             1           0           0.983146
# 7 2022-08-16 12:00:00     0.8640             1           0           0.903766
# 8 2022-08-17 11:57:00     0.7880             1           0           0.960976
# 9 2022-08-17 12:25:00     0.8840             1           0           0.913223
#
#        error_time session_phase                         error_message  \
# 0 0 days 12:29:11       Runtime         Serial write error:  Unknown.
# 1 0 days 12:29:11       Runtime         Serial write error:  Unknown.
# 2 0 days 12:23:42       Runtime         Serial write error:  Unknown.
# 3 0 days 12:23:42       Runtime         Serial write error:  Unknown.
# 4 0 days 12:23:24       Runtime         Serial write error:  Unknown.
# 5 0 days 12:23:24       Runtime         Serial write error:  Unknown.
# 6 0 days 13:50:54       Runtime         Serial write error:  Unknown.
# 7 0 days 12:33:20       Runtime         Serial write error:  Unknown.
# 8 0 days 12:22:36       Runtime  Timed out while waiting for a reply.
# 9 0 days 12:22:36       Runtime  Timed out while waiting for a reply.
#
#                                      error_exception
# 0  [[[['Serial write error:  Unknown.'], [[(array...
# 1  [[[['Serial write error:  Unknown.'], [[(array...
# 2  [[[['Serial write error:  Unknown.'], [[(array...
# 3  [[[['Serial write error:  Unknown.'], [[(array...
# 4  [[[['Serial write error:  Unknown.'], [[(array...
# 5  [[[['Serial write error:  Unknown.'], [[(array...
# 6  [[[['Serial write error:  Unknown.'], [[(array...
# 7  [[[['Serial write error:  Unknown.'], [[(array...
# 8  [[[['Timed out while waiting for a reply.'], [...
# 9  [[[['Timed out while waiting for a reply.'], [...
#
# [10 rows x 21 columns]
